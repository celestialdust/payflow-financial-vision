# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re
import json

# %%
# Load the CSV file
def load_data(file_path):
    try:
        print(f"Loading data from {file_path}...")
        df = pd.read_csv(file_path)
        print(f"Successfully loaded {len(df)} records.")
        return df
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# %%
# Load the data
file_path = "Data for Technical Challenge.csv"
df = load_data(file_path)

# Display the first few rows and data info to understand structure
if df is not None:
    print("Data Preview:")
    print(df.head())
    print("\nData Information:")
    print(df.info())
    print("\nData Statistics:")
    print(df.describe())
    print("\nMissing Values:")
    print(df.isnull().sum())
# Out:
# Loading data from Data for Technical Challenge.csv...
# Successfully loaded 5706 records.
# Data Preview:
#   Date Invoiced   Date Paid  No. Days taken to Pay  Client Name  \
# 0    2022-05-31  2024-04-05                    675            1
# 1    2023-08-16  2024-04-05                    233            1
# 2    2023-08-16  2024-04-05                    233            1
# 3    2023-08-16  2024-04-05                    233            1
# 4    2019-01-31  2019-09-17                    229            1
#
#   Invoice Reference  Invoice Amount  Paid Amount
# 0         2022-5916       105609.74    105609.74
# 1         2023-6512       263821.73    263821.73
# 2         2023-6512        90150.94     90150.94
# 3         2023-6512         8442.53      8442.53
# 4         2019-4610       102461.41    102461.40
#
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5706 entries, 0 to 5705
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date Invoiced          5706 non-null   object
#  1   Date Paid              5706 non-null   object
#  2   No. Days taken to Pay  5706 non-null   int64
#  3   Client Name            5706 non-null   int64
#  4   Invoice Reference      5706 non-null   object
#  5   Invoice Amount         5706 non-null   float64
#  6   Paid Amount            5706 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 312.2+ KB
# None
#
# Data Statistics:
#        No. Days taken to Pay  Client Name  Invoice Amount   Paid Amount
# count            5706.000000  5706.000000    5.706000e+03  5.706000e+03
# mean              143.556081   137.153172    1.214481e+05  9.579542e+04
# std               239.066240    83.956117    1.908880e+05  1.491804e+05
# min                 0.000000     1.000000    5.189780e+03  1.000000e-02
# 25%                33.000000    57.000000    2.183481e+04  1.611123e+04
# 50%                67.000000   141.000000    5.692238e+04  4.380469e+04
# 75%               146.000000   210.000000    1.348031e+05  1.074842e+05
# max              3257.000000   281.000000    2.498671e+06  2.250469e+06
#
# Missing Values:
# Date Invoiced            0
# Date Paid                0
# No. Days taken to Pay    0
# Client Name              0
# Invoice Reference        0
# Invoice Amount           0
# Paid Amount              0
# dtype: int64

# %%
def clean_data(df):
    # Create a copy to avoid modifying the original DataFrame
    cleaned_df = df.copy()
    
    # 1. Handle missing values
    print(f"Missing values before cleaning: {cleaned_df.isnull().sum().sum()}")
    
    # Fill missing numeric values with appropriate defaults
    if 'No. Days taken to Pay' in cleaned_df.columns:
        cleaned_df['No. Days taken to Pay'] = cleaned_df['No. Days taken to Pay'].fillna(0)
    
    if 'Invoice Amount' in cleaned_df.columns:
        cleaned_df['Invoice Amount'] = cleaned_df['Invoice Amount'].fillna(0)
    
    if 'Paid Amount' in cleaned_df.columns:
        cleaned_df['Paid Amount'] = cleaned_df['Paid Amount'].fillna(0)
    
    # 2. Convert date columns to datetime format
    date_columns = ['Date Invoiced', 'Date Paid']
    for col in date_columns:
        if col in cleaned_df.columns:
            # Try multiple date formats
            try:
                cleaned_df[col] = pd.to_datetime(cleaned_df[col], errors='coerce')
            except:
                print(f"Unable to convert {col} to datetime. Manual cleaning needed.")
    
    # 3. Fix the Invoice Reference format (should be YEAR-REFERENCE NUMBER)
    if 'Invoice Reference' in cleaned_df.columns:
        cleaned_df['Invoice Reference'] = cleaned_df['Invoice Reference'].fillna('Unknown')
        
        # Function to fix invoice reference format
        def fix_invoice_reference(ref):
            if isinstance(ref, str):
                # If already in YEAR-NUMBER format, return as is
                if re.match(r'^\d{4}-\d+$', ref):
                    return ref
                
                # Extract year from 'Date Invoiced' if available
                year = None
                invoice_date_idx = cleaned_df.columns.get_loc('Date Invoiced') if 'Date Invoiced' in cleaned_df.columns else None
                invoice_ref_idx = cleaned_df.columns.get_loc('Invoice Reference')
                
                if invoice_date_idx is not None:
                    row_idx = cleaned_df[cleaned_df['Invoice Reference'] == ref].index[0]
                    date_value = cleaned_df.iloc[row_idx, invoice_date_idx]
                    if isinstance(date_value, pd.Timestamp):
                        year = date_value.year
                
                # If year couldn't be extracted, use a default
                if year is None:
                    # Extract numbers from the reference
                    numbers = re.findall(r'\d+', ref)
                    if len(numbers) > 0 and len(numbers[0]) >= 4:
                        year = numbers[0][:4]  # Use first 4 digits as year
                    else:
                        year = "0000"  # Default value
                
                # Extract or create reference number
                ref_num = re.sub(r'[^\d]', '', ref)
                if not ref_num:
                    ref_num = "0000"
                
                return f"{year}-{ref_num}"
            return "0000-0000"  # Default for non-string values
        
        # Apply the function to fix references
        cleaned_df['Invoice Reference'] = cleaned_df.apply(
            lambda row: fix_invoice_reference(row['Invoice Reference']), 
            axis=1
        )
    
    # 4. Handle Client Name - ensure it's clean
    if 'Client Name' in cleaned_df.columns:
        # Convert to string if it's numeric
        if pd.api.types.is_numeric_dtype(cleaned_df['Client Name']):
            cleaned_df['Client Name'] = cleaned_df['Client Name'].astype(str)
        
        # Replace missing client names with 'Unknown'
        cleaned_df['Client Name'] = cleaned_df['Client Name'].fillna('Unknown')
    
    # 5. Check for duplicate invoices and handle them
    duplicates = cleaned_df.duplicated(subset=['Invoice Reference'], keep=False)
    if duplicates.any():
        print(f"Found {duplicates.sum()} duplicate invoice references.")
        # Keep the first occurrence for now, but flag them
        cleaned_df['Is Duplicate'] = duplicates
    
    # 6. Calculate or validate 'No. Days taken to Pay'
    if all(col in cleaned_df.columns for col in ['Date Invoiced', 'Date Paid']):
        # Calculate days to pay for rows with both dates
        has_both_dates = cleaned_df['Date Invoiced'].notna() & cleaned_df['Date Paid'].notna()
        cleaned_df.loc[has_both_dates, 'Calculated Days to Pay'] = (
            cleaned_df.loc[has_both_dates, 'Date Paid'] - 
            cleaned_df.loc[has_both_dates, 'Date Invoiced']
        ).dt.days
        
        # Check if calculated days match the provided 'No. Days taken to Pay'
        if 'No. Days taken to Pay' in cleaned_df.columns:
            days_match = (cleaned_df['Calculated Days to Pay'] == cleaned_df['No. Days taken to Pay'])
            mismatches = (~days_match) & cleaned_df['Calculated Days to Pay'].notna()
            
            if mismatches.any():
                print(f"Found {mismatches.sum()} mismatches in 'Days to Pay' calculation.")
                # Use calculated days where there are mismatches
                cleaned_df.loc[mismatches, 'No. Days taken to Pay'] = cleaned_df.loc[mismatches, 'Calculated Days to Pay']
            
            # Use calculated days where original is missing
            missing_days = cleaned_df['No. Days taken to Pay'].isna() & cleaned_df['Calculated Days to Pay'].notna()
            cleaned_df.loc[missing_days, 'No. Days taken to Pay'] = cleaned_df.loc[missing_days, 'Calculated Days to Pay']
        else:
            # If 'No. Days taken to Pay' doesn't exist, create it
            cleaned_df['No. Days taken to Pay'] = cleaned_df['Calculated Days to Pay']
    
    # 7. Add a payment status column
    if all(col in cleaned_df.columns for col in ['Invoice Amount', 'Paid Amount']):
        # Allow for small differences due to rounding
        tolerance = 0.01
        cleaned_df['Payment Status'] = 'Unknown'
        
        # Fully paid
        fully_paid = (abs(cleaned_df['Paid Amount'] - cleaned_df['Invoice Amount']) <= tolerance)
        cleaned_df.loc[fully_paid, 'Payment Status'] = 'Fully Paid'
        
        # Partially paid
        partially_paid = (cleaned_df['Paid Amount'] > 0) & (cleaned_df['Paid Amount'] < cleaned_df['Invoice Amount'] - tolerance)
        cleaned_df.loc[partially_paid, 'Payment Status'] = 'Partially Paid'
        
        # Unpaid
        unpaid = (cleaned_df['Paid Amount'] <= 0)
        cleaned_df.loc[unpaid, 'Payment Status'] = 'Unpaid'
        
        # Overpaid
        overpaid = (cleaned_df['Paid Amount'] > cleaned_df['Invoice Amount'] + tolerance)
        cleaned_df.loc[overpaid, 'Payment Status'] = 'Overpaid'
    
    # 8. Define Late Invoices (setting 30 days as threshold)
    if 'No. Days taken to Pay' in cleaned_df.columns:
        cleaned_df['Is Late'] = cleaned_df['No. Days taken to Pay'] > 30  # 30 days threshold
    
    # Clean up - drop temporary columns
    if 'Calculated Days to Pay' in cleaned_df.columns:
        cleaned_df = cleaned_df.drop(columns=['Calculated Days to Pay'])
    
    print(f"Missing values after cleaning: {cleaned_df.isnull().sum().sum()}")
    return cleaned_df

# Clean the data
cleaned_df = clean_data(df)
cleaned_df.head()
# Out:
# Missing values before cleaning: 0
# Found 3746 duplicate invoice references.
# Missing values after cleaning: 0
#   Date Invoiced  Date Paid  No. Days taken to Pay Client Name  \
# 0    2022-05-31 2024-04-05                    675           1
# 1    2023-08-16 2024-04-05                    233           1
# 2    2023-08-16 2024-04-05                    233           1
# 3    2023-08-16 2024-04-05                    233           1
# 4    2019-01-31 2019-09-17                    229           1
#
#   Invoice Reference  Invoice Amount  Paid Amount  Is Duplicate  \
# 0         2022-5916       105609.74    105609.74         False
# 1         2023-6512       263821.73    263821.73          True
# 2         2023-6512        90150.94     90150.94          True
# 3         2023-6512         8442.53      8442.53          True
# 4         2019-4610       102461.41    102461.40          True
#
#    Payment Status  Is Late
# 0      Fully Paid     True
# 1      Fully Paid     True
# 2      Fully Paid     True
# 3      Fully Paid     True
# 4  Partially Paid     True

# %%
def add_derived_metrics(df):
    enriched_df = df.copy()
    
    # 1. Add month and year columns for aggregation
    if 'Date Invoiced' in enriched_df.columns and pd.api.types.is_datetime64_dtype(enriched_df['Date Invoiced']):
        enriched_df['Invoice Month'] = enriched_df['Date Invoiced'].dt.to_period('M')
        enriched_df['Invoice Year'] = enriched_df['Date Invoiced'].dt.year
    
    if 'Date Paid' in enriched_df.columns and pd.api.types.is_datetime64_dtype(enriched_df['Date Paid']):
        enriched_df['Payment Month'] = enriched_df['Date Paid'].dt.to_period('M')
        enriched_df['Payment Year'] = enriched_df['Date Paid'].dt.year
    
    # 2. Flag outstanding invoices (not paid or partially paid)
    if 'Payment Status' in enriched_df.columns:
        enriched_df['Is Outstanding'] = enriched_df['Payment Status'].isin(['Unpaid', 'Partially Paid'])
    
    # 3. Calculate amount due (Invoice Amount - Paid Amount)
    if all(col in enriched_df.columns for col in ['Invoice Amount', 'Paid Amount']):
        enriched_df['Amount Due'] = enriched_df['Invoice Amount'] - enriched_df['Paid Amount']
        # Ensure no negative values for Amount Due (handle overpayments)
        enriched_df['Amount Due'] = enriched_df['Amount Due'].clip(lower=0)
    
    return enriched_df

# Add derived metrics
enriched_df = add_derived_metrics(cleaned_df)
enriched_df.head()
# Out:
#   Date Invoiced  Date Paid  No. Days taken to Pay Client Name  \
# 0    2022-05-31 2024-04-05                    675           1
# 1    2023-08-16 2024-04-05                    233           1
# 2    2023-08-16 2024-04-05                    233           1
# 3    2023-08-16 2024-04-05                    233           1
# 4    2019-01-31 2019-09-17                    229           1
#
#   Invoice Reference  Invoice Amount  Paid Amount  Is Duplicate  \
# 0         2022-5916       105609.74    105609.74         False
# 1         2023-6512       263821.73    263821.73          True
# 2         2023-6512        90150.94     90150.94          True
# 3         2023-6512         8442.53      8442.53          True
# 4         2019-4610       102461.41    102461.40          True
#
#    Payment Status  Is Late Invoice Month  Invoice Year Payment Month  \
# 0      Fully Paid     True       2022-05          2022       2024-04
# 1      Fully Paid     True       2023-08          2023       2024-04
# 2      Fully Paid     True       2023-08          2023       2024-04
# 3      Fully Paid     True       2023-08          2023       2024-04
# 4  Partially Paid     True       2019-01          2019       2019-09
#
#    Payment Year  Is Outstanding  Amount Due
# 0          2024           False        0.00
# 1          2024           False        0.00
# 2          2024           False        0.00
# 3          2024           False        0.00
# 4          2019            True        0.01

# %%
def calculate_company_metrics(df):
    # Get unique companies
    companies = df['Client Name'].unique()
    
    company_metrics = {}
    for company in companies:
        company_data = df[df['Client Name'] == company]
        
        # Calculate basic metrics for each company
        metrics = {
            'total_invoices': len(company_data),
            'total_invoiced': company_data['Invoice Amount'].sum(),
            'total_paid': company_data['Paid Amount'].sum(),
            'average_days_to_pay': company_data['No. Days taken to Pay'].mean(),
            'late_invoices_count': company_data['Is Late'].sum(),
            'late_invoices_percentage': (company_data['Is Late'].sum() / len(company_data)) * 100 if len(company_data) > 0 else 0,
            'outstanding_invoices': company_data['Is Outstanding'].sum(),
            'outstanding_amount': company_data['Amount Due'].sum()
        }
        
        # Calculate monthly totals
        if 'Invoice Month' in company_data.columns:
            monthly_invoiced = company_data.groupby('Invoice Month')['Invoice Amount'].sum()
            metrics['monthly_invoiced'] = monthly_invoiced.to_dict()
        
        if 'Payment Month' in company_data.columns:
            monthly_paid = company_data.groupby('Payment Month')['Paid Amount'].sum()
            metrics['monthly_paid'] = monthly_paid.to_dict()
        
        # Payment status breakdown
        if 'Payment Status' in company_data.columns:
            status_counts = company_data['Payment Status'].value_counts()
            metrics['payment_status_breakdown'] = status_counts.to_dict()
        
        company_metrics[company] = metrics
    
    return company_metrics

# Calculate company metrics
company_metrics = calculate_company_metrics(enriched_df)
company_metrics
# Out:
# {'1': {'total_invoices': 115,
#   'total_invoiced': 30077153.9,
#   'total_paid': 29533057.6,
#   'average_days_to_pay': 93.98260869565217,
#   'late_invoices_count': 102,
#   'late_invoices_percentage': 88.69565217391305,
#   'outstanding_invoices': 6,
#   'outstanding_amount': 544096.3,
#   'monthly_invoiced': {Period('2018-03', 'M'): 580549.48,
#    Period('2018-05', 'M'): 727760.7100000001,
#    Period('2018-06', 'M'): 354918.1,
#    Period('2018-07', 'M'): 995112.84,
#    Period('2018-09', 'M'): 468072.12,
#    Period('2018-11', 'M'): 330246.28,
#    Period('2019-01', 'M'): 1491623.93,
#    Period('2019-02', 'M'): 57977.590000000004,
#    Period('2019-04', 'M'): 75567.44,
#    Period('2019-05', 'M'): 212833.72999999998,
#    Period('2019-07', 'M'): 908150.22,
#    Period('2019-08', 'M'): 60401.71,
#    Period('2019-10', 'M'): 47239.799999999996,
#    Period('2019-11', 'M'): 373207.88,
#    Period('2019-12', 'M'): 504920.29,
#    Period('2022-01', 'M'): 571605.74,
#    Period('2022-02', 'M'): 982309.2100000001,
#    Period('2022-03', 'M'): 1927977.1400000001,
#    Period('2022-04', 'M'): 1353493.29,
#    Period('2022-05', 'M'): 877620.89,
#    Period('2022-06', 'M'): 1785717.64,
#    Period('2022-07', 'M'): 422106.26,
#    Period('2022-08', 'M'): 506162.84,
#    Period('2022-09', 'M'): 796325.0800000001,
#    Period('2022-10', 'M'): 1141462.8,
#    Period('2022-11', 'M'): 359566.01,
#    Period('2022-12', 'M'): 568525.51,
#    Period('2023-01', 'M'): 776978.75,
#    Period('2023-02', 'M'): 777633.58,
#    Period('2023-03', 'M'): 1231637.47,
#    Period('2023-04', 'M'): 1121888.46,
#    Period('2023-05', 'M'): 1155073.34,
#    Period('2023-06', 'M'): 1015114.75,
#    Period('2023-07', 'M'): 790922.6,
#    Period('2023-08', 'M'): 1199626.0,
#    Period('2023-09', 'M'): 1293383.55,
#    Period('2023-10', 'M'): 182622.49,
#    Period('2023-11', 'M'): 503724.14,
#    Period('2023-12', 'M'): 1179829.3,
#    Period('2024-02', 'M'): 367264.94},
#   'monthly_paid': {Period('2018-07', 'M'): 1308310.19,
#    Period('2018-08', 'M'): 710029.5,
#    Period('2018-10', 'M'): 285083.34,
#    Period('2019-01', 'M'): 1113202.39,
#    Period('2019-02', 'M'): 780210.42,
#    Period('2019-04', 'M'): 445194.64999999997,
#    Period('2019-07', 'M'): 339955.18,
#    Period('2019-08', 'M'): 239833.9,
#    Period('2019-09', 'M'): 221735.04,
#    Period('2019-12', 'M'): 545557.84,
#    Period('2020-03', 'M'): 552053.86,
#    Period('2020-05', 'M'): 504920.29,
#    Period('2022-03', 'M'): 1041800.98,
#    Period('2022-04', 'M'): 697705.3700000001,
#    Period('2022-05', 'M'): 404745.4,
#    Period('2022-06', 'M'): 772011.15,
#    Period('2022-07', 'M'): 2636818.7199999997,
#    Period('2022-09', 'M'): 776562.85,
#    Period('2022-10', 'M'): 1078746.1,
#    Period('2022-11', 'M'): 960591.13,
#    Period('2022-12', 'M'): 347125.87,
#    Period('2023-01', 'M'): 1176833.14,
#    Period('2023-02', 'M'): 985380.2799999999,
#    Period('2023-03', 'M'): 36633.88,
#    Period('2023-04', 'M'): 1425319.35,
#    Period('2023-06', 'M'): 1937863.04,
#    Period('2023-07', 'M'): 415662.89,
#    Period('2023-08', 'M'): 2170188.09,
#    Period('2023-09', 'M'): 790922.6,
#    Period('2023-10', 'M'): 68823.04,
#    Period('2023-11', 'M'): 2101128.2,
#    Period('2024-01', 'M'): 27843.52,
#    Period('2024-02', 'M'): 619146.22,
#    Period('2024-03', 'M'): 1179829.3,
#    Period('2024-04', 'M'): 468024.94,
#    Period('2024-05', 'M'): 367264.94},
#   'payment_status_breakdown': {'Fully Paid': 109, 'Partially Paid': 6}},
#  '2': {'total_invoices': 1,
#   'total_invoiced': 15557.24,
#   'total_paid': 15557.24,
#   'average_days_to_pay': 144.0,
#   'late_invoices_count': 1,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2014-11', 'M'): 15557.24},
#   'monthly_paid': {Period('2015-04', 'M'): 15557.24},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '3': {'total_invoices': 1,
#   'total_invoiced': 148081.97,
#   'total_paid': 148081.97,
#   'average_days_to_pay': 28.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2022-09', 'M'): 148081.97},
#   'monthly_paid': {Period('2022-10', 'M'): 148081.97},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '4': {'total_invoices': 30,
#   'total_invoiced': 777400.2400000002,
#   'total_paid': 683108.4300000003,
#   'average_days_to_pay': 223.33333333333334,
#   'late_invoices_count': 27,
#   'late_invoices_percentage': 90.0,
#   'outstanding_invoices': 4,
#   'outstanding_amount': 94291.81,
#   'monthly_invoiced': {Period('2015-01', 'M'): 21834.81,
#    Period('2015-02', 'M'): 21834.81,
#    Period('2015-03', 'M'): 21834.81,
#    Period('2015-04', 'M'): 21834.81,
#    Period('2015-05', 'M'): 40111.33,
#    Period('2015-06', 'M'): 21834.81,
#    Period('2015-07', 'M'): 21834.81,
#    Period('2015-08', 'M'): 21834.81,
#    Period('2015-09', 'M'): 21834.81,
#    Period('2015-10', 'M'): 43669.62,
#    Period('2015-11', 'M'): 21834.81,
#    Period('2015-12', 'M'): 21834.81,
#    Period('2016-01', 'M'): 21834.81,
#    Period('2016-02', 'M'): 21834.81,
#    Period('2016-03', 'M'): 21834.81,
#    Period('2016-04', 'M'): 21834.81,
#    Period('2016-06', 'M'): 72457.01,
#    Period('2016-08', 'M'): 144914.02,
#    Period('2016-09', 'M'): 21834.81,
#    Period('2016-10', 'M'): 21834.81,
#    Period('2016-11', 'M'): 21834.81,
#    Period('2016-12', 'M'): 21834.81,
#    Period('2017-01', 'M'): 12736.3,
#    Period('2017-02', 'M'): 12736.3,
#    Period('2017-03', 'M'): 12736.3,
#    Period('2017-05', 'M'): 32276.48,
#    Period('2017-06', 'M'): 12736.3},
#   'monthly_paid': {Period('2015-03', 'M'): 21834.81,
#    Period('2015-05', 'M'): 65504.43000000001,
#    Period('2016-04', 'M'): 132032.47,
#    Period('2017-03', 'M'): 241906.8,
#    Period('2017-06', 'M'): 221829.92},
#   'payment_status_breakdown': {'Fully Paid': 26, 'Partially Paid': 4}},
#  '5': {'total_invoices': 2,
#   'total_invoiced': 21662.94,
#   'total_paid': 21662.94,
#   'average_days_to_pay': 11.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2018-01', 'M'): 21662.94},
#   'monthly_paid': {Period('2018-01', 'M'): 16473.16,
#    Period('2018-02', 'M'): 5189.78},
#   'payment_status_breakdown': {'Fully Paid': 2}},
#  '6': {'total_invoices': 21,
#   'total_invoiced': 1909403.8000000003,
#   'total_paid': 1866343.7000000002,
#   'average_days_to_pay': 384.42857142857144,
#   'late_invoices_count': 21,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 43060.1,
#   'monthly_invoiced': {Period('2015-01', 'M'): 108348.87,
#    Period('2015-02', 'M'): 125238.89,
#    Period('2015-03', 'M'): 149716.6,
#    Period('2015-04', 'M'): 265903.14,
#    Period('2015-05', 'M'): 327442.31,
#    Period('2015-06', 'M'): 367397.04,
#    Period('2015-08', 'M'): 212759.08,
#    Period('2016-03', 'M'): 15144.39,
#    Period('2016-05', 'M'): 83514.83,
#    Period('2016-06', 'M'): 52687.84,
#    Period('2016-07', 'M'): 83232.76,
#    Period('2016-09', 'M'): 118018.05},
#   'monthly_paid': {Period('2015-03', 'M'): 108348.87,
#    Period('2015-05', 'M'): 125238.89,
#    Period('2016-01', 'M'): 467745.35,
#    Period('2016-03', 'M'): 855472.82,
#    Period('2016-07', 'M'): 15144.39,
#    Period('2018-07', 'M'): 294393.38},
#   'payment_status_breakdown': {'Fully Paid': 19, 'Partially Paid': 2}},
#  '7': {'total_invoices': 5,
#   'total_invoiced': 438296.9,
#   'total_paid': 175318.76,
#   'average_days_to_pay': 27.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 4,
#   'outstanding_amount': 262978.14,
#   'monthly_invoiced': {Period('2018-07', 'M'): 87659.38,
#    Period('2018-08', 'M'): 350637.52},
#   'monthly_paid': {Period('2018-08', 'M'): 87659.38,
#    Period('2018-09', 'M'): 87659.38},
#   'payment_status_breakdown': {'Partially Paid': 4, 'Fully Paid': 1}},
#  '8': {'total_invoices': 1,
#   'total_invoiced': 54120.07,
#   'total_paid': 54120.07,
#   'average_days_to_pay': 0.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2015-12', 'M'): 54120.07},
#   'monthly_paid': {Period('2015-12', 'M'): 54120.07},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '9': {'total_invoices': 57,
#   'total_invoiced': 1881384.24,
#   'total_paid': 1851097.0000000002,
#   'average_days_to_pay': 31.666666666666668,
#   'late_invoices_count': 12,
#   'late_invoices_percentage': 21.052631578947366,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 30287.24,
#   'monthly_invoiced': {Period('2022-04', 'M'): 97650.57,
#    Period('2022-09', 'M'): 90108.0,
#    Period('2022-10', 'M'): 128439.91999999998,
#    Period('2022-11', 'M'): 123764.83,
#    Period('2022-12', 'M'): 171094.39,
#    Period('2023-01', 'M'): 37103.78,
#    Period('2023-02', 'M'): 37103.78,
#    Period('2023-03', 'M'): 52277.71,
#    Period('2023-04', 'M'): 97026.34,
#    Period('2023-05', 'M'): 37103.78,
#    Period('2023-06', 'M'): 150586.13,
#    Period('2023-07', 'M'): 52277.71,
#    Period('2023-08', 'M'): 246570.03,
#    Period('2023-09', 'M'): 156629.47,
#    Period('2023-10', 'M'): 37103.78,
#    Period('2023-11', 'M'): 37103.78,
#    Period('2023-12', 'M'): 37103.78,
#    Period('2024-01', 'M'): 156629.47,
#    Period('2024-02', 'M'): 61499.43,
#    Period('2024-03', 'M'): 37103.78,
#    Period('2024-04', 'M'): 37103.78},
#   'monthly_paid': {Period('2022-04', 'M'): 56565.950000000004,
#    Period('2022-05', 'M'): 10797.38,
#    Period('2022-10', 'M'): 53004.22,
#    Period('2022-11', 'M'): 165543.69999999998,
#    Period('2022-12', 'M'): 123764.83,
#    Period('2023-01', 'M'): 171094.39,
#    Period('2023-02', 'M'): 37103.78,
#    Period('2023-03', 'M'): 37103.78,
#    Period('2023-04', 'M'): 52277.71,
#    Period('2023-05', 'M'): 97026.34,
#    Period('2023-07', 'M'): 187689.91,
#    Period('2023-08', 'M'): 52277.71,
#    Period('2023-09', 'M'): 246570.03,
#    Period('2023-10', 'M'): 156629.47,
#    Period('2023-11', 'M'): 37103.78,
#    Period('2023-12', 'M'): 37103.78,
#    Period('2024-02', 'M'): 119525.69,
#    Period('2024-05', 'M'): 209914.55},
#   'payment_status_breakdown': {'Fully Paid': 55, 'Partially Paid': 2}},
#  '10': {'total_invoices': 23,
#   'total_invoiced': 1808819.36,
#   'total_paid': 1590965.16,
#   'average_days_to_pay': 311.1304347826087,
#   'late_invoices_count': 23,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 5,
#   'outstanding_amount': 217854.19999999998,
#   'monthly_invoiced': {Period('2014-09', 'M'): 49640.59,
#    Period('2014-12', 'M'): 357845.57,
#    Period('2015-01', 'M'): 317135.39,
#    Period('2015-03', 'M'): 203711.7,
#    Period('2015-04', 'M'): 177628.16,
#    Period('2015-06', 'M'): 226297.54,
#    Period('2015-07', 'M'): 113148.77,
#    Period('2015-08', 'M'): 113148.77,
#    Period('2015-10', 'M'): 75505.23,
#    Period('2015-12', 'M'): 113148.77,
#    Period('2016-02', 'M'): 40989.94,
#    Period('2016-04', 'M'): 20618.93},
#   'monthly_paid': {Period('2015-02', 'M'): 81917.06999999999,
#    Period('2015-06', 'M'): 138063.62,
#    Period('2015-09', 'M'): 551129.55,
#    Period('2015-11', 'M'): 226297.54,
#    Period('2016-05', 'M'): 261377.44,
#    Period('2016-07', 'M'): 90397.41,
#    Period('2016-08', 'M'): 67024.89,
#    Period('2016-11', 'M'): 113148.77,
#    Period('2017-12', 'M'): 61608.87},
#   'payment_status_breakdown': {'Fully Paid': 18, 'Partially Paid': 5}},
#  '11': {'total_invoices': 9,
#   'total_invoiced': 96216.64,
#   'total_paid': 96216.64,
#   'average_days_to_pay': 154.11111111111111,
#   'late_invoices_count': 9,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2014-10', 'M'): 18283.64,
#    Period('2015-01', 'M'): 18283.64,
#    Period('2015-09', 'M'): 59649.36},
#   'monthly_paid': {Period('2015-09', 'M'): 36567.28,
#    Period('2015-11', 'M'): 59649.36},
#   'payment_status_breakdown': {'Fully Paid': 9}},
#  '12': {'total_invoices': 3,
#   'total_invoiced': 986193.21,
#   'total_paid': 986193.21,
#   'average_days_to_pay': 93.33333333333333,
#   'late_invoices_count': 3,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2019-10', 'M'): 336815.22000000003,
#    Period('2019-11', 'M'): 649377.99},
#   'monthly_paid': {Period('2020-01', 'M'): 969428.38,
#    Period('2020-02', 'M'): 16764.83},
#   'payment_status_breakdown': {'Fully Paid': 3}},
#  '13': {'total_invoices': 108,
#   'total_invoiced': 15027920.37,
#   'total_paid': 11753835.6,
#   'average_days_to_pay': 160.64814814814815,
#   'late_invoices_count': 106,
#   'late_invoices_percentage': 98.14814814814815,
#   'outstanding_invoices': 69,
#   'outstanding_amount': 3274084.77,
#   'monthly_invoiced': {Period('2019-10', 'M'): 5054867.65,
#    Period('2019-11', 'M'): 176461.7,
#    Period('2019-12', 'M'): 1694530.68,
#    Period('2022-01', 'M'): 173895.24,
#    Period('2022-02', 'M'): 109636.22,
#    Period('2022-03', 'M'): 69975.7,
#    Period('2022-04', 'M'): 109620.69,
#    Period('2022-05', 'M'): 106240.86,
#    Period('2022-06', 'M'): 412696.83,
#    Period('2022-07', 'M'): 899003.4,
#    Period('2022-08', 'M'): 73655.3,
#    Period('2022-09', 'M'): 512905.20999999996,
#    Period('2022-10', 'M'): 490889.3,
#    Period('2022-11', 'M'): 165228.42,
#    Period('2022-12', 'M'): 837336.57,
#    Period('2023-01', 'M'): 310425.66,
#    Period('2023-02', 'M'): 105543.16,
#    Period('2023-03', 'M'): 610603.8,
#    Period('2023-04', 'M'): 254227.93,
#    Period('2023-05', 'M'): 217220.59,
#    Period('2023-06', 'M'): 350395.28,
#    Period('2023-07', 'M'): 448308.32,
#    Period('2023-09', 'M'): 195540.82,
#    Period('2023-11', 'M'): 1167961.68,
#    Period('2023-12', 'M'): 14431.94,
#    Period('2024-01', 'M'): 171640.29,
#    Period('2024-02', 'M'): 294677.13},
#   'monthly_paid': {Period('2020-01', 'M'): 2804619.2,
#    Period('2020-02', 'M'): 142172.41,
#    Period('2020-03', 'M'): 990088.04,
#    Period('2020-04', 'M'): 39540.47,
#    Period('2020-06', 'M'): 7914.98,
#    Period('2022-02', 'M'): 37771.92,
#    Period('2022-04', 'M'): 165027.53,
#    Period('2022-05', 'M'): 133287.04,
#    Period('2022-06', 'M'): 104400.66,
#    Period('2022-07', 'M'): 101727.34,
#    Period('2022-08', 'M'): 388652.98000000004,
#    Period('2022-09', 'M'): 515110.92000000004,
#    Period('2022-10', 'M'): 176243.63,
#    Period('2022-11', 'M'): 70147.9,
#    Period('2022-12', 'M'): 997396.03,
#    Period('2023-01', 'M'): 460648.13,
#    Period('2023-02', 'M'): 119486.57999999999,
#    Period('2023-03', 'M'): 534058.56,
#    Period('2023-04', 'M'): 395649.02,
#    Period('2023-06', 'M'): 575864.3200000001,
#    Period('2023-07', 'M'): 74562.15,
#    Period('2023-09', 'M'): 705200.66,
#    Period('2023-10', 'M'): 365203.61,
#    Period('2023-11', 'M'): 189553.94,
#    Period('2024-01', 'M'): 209044.36,
#    Period('2024-02', 'M'): 979023.84,
#    Period('2024-03', 'M'): 190794.5,
#    Period('2024-05', 'M'): 280644.88},
#   'payment_status_breakdown': {'Partially Paid': 69, 'Fully Paid': 39}},
#  '14': {'total_invoices': 13,
#   'total_invoiced': 2066665.4200000004,
#   'total_paid': 2066665.4200000004,
#   'average_days_to_pay': 49.84615384615385,
#   'late_invoices_count': 12,
#   'late_invoices_percentage': 92.3076923076923,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2017-05', 'M'): 27885.61,
#    Period('2017-08', 'M'): 27885.61,
#    Period('2017-11', 'M'): 41670.12,
#    Period('2017-12', 'M'): 119845.12,
#    Period('2019-08', 'M'): 1849378.96},
#   'monthly_paid': {Period('2017-06', 'M'): 27885.61,
#    Period('2017-11', 'M'): 27885.61,
#    Period('2018-02', 'M'): 161515.24,
#    Period('2019-10', 'M'): 1849378.96},
#   'payment_status_breakdown': {'Fully Paid': 13}},
#  '15': {'total_invoices': 280,
#   'total_invoiced': 26881541.49,
#   'total_paid': 25987685.42,
#   'average_days_to_pay': 51.24285714285714,
#   'late_invoices_count': 175,
#   'late_invoices_percentage': 62.5,
#   'outstanding_invoices': 10,
#   'outstanding_amount': 893856.07,
#   'monthly_invoiced': {Period('2015-08', 'M'): 102830.49,
#    Period('2015-11', 'M'): 2484264.3000000003,
#    Period('2015-12', 'M'): 1994581.17,
#    Period('2016-01', 'M'): 2153949.59,
#    Period('2016-02', 'M'): 77526.2,
#    Period('2016-03', 'M'): 1993711.98,
#    Period('2016-04', 'M'): 2381431.29,
#    Period('2016-05', 'M'): 307027.14,
#    Period('2016-06', 'M'): 904626.08,
#    Period('2016-11', 'M'): 39855.09,
#    Period('2016-12', 'M'): 35128.67,
#    Period('2017-01', 'M'): 79710.18,
#    Period('2017-02', 'M'): 221905.82,
#    Period('2017-03', 'M'): 33256.06,
#    Period('2017-04', 'M'): 261990.21,
#    Period('2017-05', 'M'): 318889.68,
#    Period('2017-06', 'M'): 352417.24,
#    Period('2017-07', 'M'): 363379.85,
#    Period('2017-08', 'M'): 340468.9,
#    Period('2017-09', 'M'): 396660.83,
#    Period('2017-10', 'M'): 400481.19,
#    Period('2017-11', 'M'): 409092.49,
#    Period('2017-12', 'M'): 402824.48,
#    Period('2018-01', 'M'): 781715.0599999999,
#    Period('2018-02', 'M'): 408377.8,
#    Period('2018-03', 'M'): 405926.01,
#    Period('2018-04', 'M'): 371032.45,
#    Period('2018-05', 'M'): 414763.03,
#    Period('2018-06', 'M'): 518201.64,
#    Period('2018-07', 'M'): 815392.0,
#    Period('2018-08', 'M'): 1109086.18,
#    Period('2018-09', 'M'): 300080.06,
#    Period('2018-10', 'M'): 133100.76,
#    Period('2018-11', 'M'): 889911.9600000001,
#    Period('2018-12', 'M'): 704974.93,
#    Period('2019-01', 'M'): 244580.31,
#    Period('2019-02', 'M'): 851828.9600000001,
#    Period('2019-03', 'M'): 781930.6,
#    Period('2019-04', 'M'): 429672.43,
#    Period('2019-05', 'M'): 370410.2,
#    Period('2019-06', 'M'): 370410.2,
#    Period('2019-07', 'M'): 370410.2,
#    Period('2019-08', 'M'): 167038.46,
#    Period('2019-09', 'M'): 100013.75,
#    Period('2019-10', 'M'): 100013.75,
#    Period('2019-11', 'M'): 93330.91,
#    Period('2019-12', 'M'): 93330.91},
#   'monthly_paid': {Period('2015-09', 'M'): 102830.49,
#    Period('2015-12', 'M'): 2484264.3000000003,
#    Period('2016-01', 'M'): 1994581.17,
#    Period('2016-02', 'M'): 2153949.59,
#    Period('2016-04', 'M'): 2071238.1800000002,
#    Period('2016-08', 'M'): 627490.12,
#    Period('2016-10', 'M'): 1144471.3900000001,
#    Period('2016-11', 'M'): 26128.72,
#    Period('2016-12', 'M'): 742566.23,
#    Period('2017-01', 'M'): 135895.46,
#    Period('2017-02', 'M'): 114838.84999999999,
#    Period('2017-03', 'M'): 93708.66,
#    Period('2017-04', 'M'): 150082.78,
#    Period('2017-05', 'M'): 273360.65,
#    Period('2017-06', 'M'): 318889.68,
#    Period('2017-07', 'M'): 800529.41,
#    Period('2017-08', 'M'): 363379.85,
#    Period('2017-10', 'M'): 737129.73,
#    Period('2017-11', 'M'): 400481.19,
#    Period('2017-12', 'M'): 409092.49,
#    Period('2018-01', 'M'): 402824.48,
#    Period('2018-02', 'M'): 781715.0599999999,
#    Period('2018-03', 'M'): 408377.8,
#    Period('2018-04', 'M'): 405926.01,
#    Period('2018-05', 'M'): 371032.45,
#    Period('2018-06', 'M'): 146038.94999999998,
#    Period('2018-07', 'M'): 786925.72,
#    Period('2018-08', 'M'): 504904.36,
#    Period('2018-09', 'M'): 815392.0,
#    Period('2018-10', 'M'): 507494.52,
#    Period('2018-11', 'M'): 144287.56,
#    Period('2019-01', 'M'): 1116450.47,
#    Period('2019-02', 'M'): 782823.8,
#    Period('2019-03', 'M'): 454783.56,
#    Period('2019-04', 'M'): 1057005.72,
#    Period('2019-05', 'M'): 429672.43,
#    Period('2019-06', 'M'): 370410.2,
#    Period('2019-07', 'M'): 432573.41000000003,
#    Period('2019-11', 'M'): 537448.66,
#    Period('2020-01', 'M'): 293358.41,
#    Period('2020-02', 'M'): 93330.91},
#   'payment_status_breakdown': {'Fully Paid': 270, 'Partially Paid': 10}},
#  '16': {'total_invoices': 1,
#   'total_invoiced': 63581.85,
#   'total_paid': 63581.85,
#   'average_days_to_pay': 34.0,
#   'late_invoices_count': 1,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2014-12', 'M'): 63581.85},
#   'monthly_paid': {Period('2015-02', 'M'): 63581.85},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '17': {'total_invoices': 16,
#   'total_invoiced': 791594.47,
#   'total_paid': 791594.47,
#   'average_days_to_pay': 121.4375,
#   'late_invoices_count': 12,
#   'late_invoices_percentage': 75.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2022-01', 'M'): 373469.02,
#    Period('2022-02', 'M'): 156100.41,
#    Period('2022-03', 'M'): 17221.94,
#    Period('2022-04', 'M'): 33136.6,
#    Period('2022-05', 'M'): 68773.55,
#    Period('2022-07', 'M'): 27704.81,
#    Period('2022-12', 'M'): 76085.74,
#    Period('2023-02', 'M'): 39102.4},
#   'monthly_paid': {Period('2022-03', 'M'): 459534.47,
#    Period('2022-04', 'M'): 120393.5,
#    Period('2022-07', 'M'): 96478.36,
#    Period('2022-12', 'M'): 6492.28,
#    Period('2023-12', 'M'): 108695.86},
#   'payment_status_breakdown': {'Fully Paid': 16}},
#  '18': {'total_invoices': 1,
#   'total_invoiced': 10001.9,
#   'total_paid': 10001.9,
#   'average_days_to_pay': 140.0,
#   'late_invoices_count': 1,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2016-10', 'M'): 10001.9},
#   'monthly_paid': {Period('2017-03', 'M'): 10001.9},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '19': {'total_invoices': 19,
#   'total_invoiced': 1106443.82,
#   'total_paid': 734475.06,
#   'average_days_to_pay': 73.05263157894737,
#   'late_invoices_count': 10,
#   'late_invoices_percentage': 52.63157894736842,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 371968.76,
#   'monthly_invoiced': {Period('2014-08', 'M'): 12736.3,
#    Period('2015-08', 'M'): 96133.3,
#    Period('2015-09', 'M'): 743937.54,
#    Period('2015-10', 'M'): 11178.58,
#    Period('2017-01', 'M'): 15557.24,
#    Period('2017-02', 'M'): 15557.24,
#    Period('2017-03', 'M'): 43442.85,
#    Period('2017-04', 'M'): 43442.85,
#    Period('2017-05', 'M'): 15557.24,
#    Period('2017-06', 'M'): 15557.24,
#    Period('2017-07', 'M'): 15557.24,
#    Period('2017-08', 'M'): 15557.24,
#    Period('2017-09', 'M'): 15557.24,
#    Period('2017-10', 'M'): 15557.24,
#    Period('2017-11', 'M'): 15557.24,
#    Period('2017-12', 'M'): 15557.24},
#   'monthly_paid': {Period('2015-07', 'M'): 12736.3,
#    Period('2015-09', 'M'): 96133.3,
#    Period('2015-12', 'M'): 170593.77,
#    Period('2017-02', 'M'): 15557.24,
#    Period('2017-03', 'M'): 228110.83,
#    Period('2017-04', 'M'): 43442.85,
#    Period('2017-05', 'M'): 43442.85,
#    Period('2017-07', 'M'): 15557.24,
#    Period('2017-08', 'M'): 15557.24,
#    Period('2017-09', 'M'): 31114.48,
#    Period('2017-11', 'M'): 15557.24,
#    Period('2017-12', 'M'): 31114.48,
#    Period('2018-02', 'M'): 15557.24},
#   'payment_status_breakdown': {'Fully Paid': 17, 'Partially Paid': 2}},
#  '20': {'total_invoices': 23,
#   'total_invoiced': 6030907.250000001,
#   'total_paid': 5162919.180000001,
#   'average_days_to_pay': 75.78260869565217,
#   'late_invoices_count': 22,
#   'late_invoices_percentage': 95.65217391304348,
#   'outstanding_invoices': 3,
#   'outstanding_amount': 867988.07,
#   'monthly_invoiced': {Period('2018-11', 'M'): 53494.74,
#    Period('2018-12', 'M'): 100188.8,
#    Period('2019-04', 'M'): 476199.29,
#    Period('2019-05', 'M'): 920242.47,
#    Period('2022-02', 'M'): 4115941.58,
#    Period('2022-10', 'M'): 364840.37},
#   'monthly_paid': {Period('2019-03', 'M'): 126936.17000000001,
#    Period('2019-07', 'M'): 584483.76,
#    Period('2019-09', 'M'): 811958.0,
#    Period('2022-02', 'M'): 0.01,
#    Period('2022-03', 'M'): 3274700.87,
#    Period('2023-02', 'M'): 282422.46,
#    Period('2023-03', 'M'): 82417.91},
#   'payment_status_breakdown': {'Fully Paid': 19,
#    'Partially Paid': 3,
#    'Unknown': 1}},
#  '21': {'total_invoices': 17,
#   'total_invoiced': 2952310.1900000004,
#   'total_paid': 2648370.1400000006,
#   'average_days_to_pay': 40.705882352941174,
#   'late_invoices_count': 6,
#   'late_invoices_percentage': 35.294117647058826,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 303940.05,
#   'monthly_invoiced': {Period('2023-07', 'M'): 214341.16,
#    Period('2023-11', 'M'): 298717.39,
#    Period('2023-12', 'M'): 368446.34,
#    Period('2024-02', 'M'): 1303449.68,
#    Period('2024-03', 'M'): 767355.62},
#   'monthly_paid': {Period('2023-07', 'M'): 214341.16,
#    Period('2024-01', 'M'): 368446.34,
#    Period('2024-03', 'M'): 1298227.02,
#    Period('2024-04', 'M'): 767355.62},
#   'payment_status_breakdown': {'Fully Paid': 15, 'Partially Paid': 2}},
#  '22': {'total_invoices': 35,
#   'total_invoiced': 2893831.89,
#   'total_paid': 1817200.9299999997,
#   'average_days_to_pay': 62.8,
#   'late_invoices_count': 21,
#   'late_invoices_percentage': 60.0,
#   'outstanding_invoices': 20,
#   'outstanding_amount': 1076630.96,
#   'monthly_invoiced': {Period('2014-12', 'M'): 417760.17000000004,
#    Period('2015-02', 'M'): 823573.72,
#    Period('2015-03', 'M'): 371440.2,
#    Period('2015-05', 'M'): 610703.88,
#    Period('2015-06', 'M'): 209879.44,
#    Period('2015-07', 'M'): 21487.28,
#    Period('2015-08', 'M'): 22718.92,
#    Period('2015-12', 'M'): 76064.88,
#    Period('2016-06', 'M'): 127805.11,
#    Period('2016-08', 'M'): 57964.24,
#    Period('2016-09', 'M'): 14868.0,
#    Period('2016-11', 'M'): 54120.07,
#    Period('2016-12', 'M'): 33968.3,
#    Period('2017-01', 'M'): 32779.9,
#    Period('2017-02', 'M'): 18697.78},
#   'monthly_paid': {Period('2015-01', 'M'): 308129.03,
#    Period('2015-02', 'M'): 501061.41000000003,
#    Period('2015-06', 'M'): 185720.1,
#    Period('2015-08', 'M'): 512207.45,
#    Period('2016-01', 'M'): 56825.899999999994,
#    Period('2016-07', 'M'): 28982.120000000003,
#    Period('2016-10', 'M'): 84708.87,
#    Period('2017-05', 'M'): 139566.05},
#   'payment_status_breakdown': {'Partially Paid': 20, 'Fully Paid': 15}},
#  '23': {'total_invoices': 4,
#   'total_invoiced': 243357.51,
#   'total_paid': 243357.51,
#   'average_days_to_pay': 47.5,
#   'late_invoices_count': 3,
#   'late_invoices_percentage': 75.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2019-04', 'M'): 17435.27,
#    Period('2019-05', 'M'): 31578.29,
#    Period('2019-06', 'M'): 25512.0,
#    Period('2022-09', 'M'): 168831.95},
#   'monthly_paid': {Period('2019-06', 'M'): 17435.27,
#    Period('2019-07', 'M'): 31578.29,
#    Period('2019-09', 'M'): 25512.0,
#    Period('2022-10', 'M'): 168831.95},
#   'payment_status_breakdown': {'Fully Paid': 4}},
#  '24': {'total_invoices': 1,
#   'total_invoiced': 34637.52,
#   'total_paid': 34637.52,
#   'average_days_to_pay': 28.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2022-01', 'M'): 34637.52},
#   'monthly_paid': {Period('2022-02', 'M'): 34637.52},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '25': {'total_invoices': 12,
#   'total_invoiced': 362555.11,
#   'total_paid': 347722.92,
#   'average_days_to_pay': 170.66666666666666,
#   'late_invoices_count': 11,
#   'late_invoices_percentage': 91.66666666666666,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 14832.19,
#   'monthly_invoiced': {Period('2014-12', 'M'): 41670.12,
#    Period('2015-01', 'M'): 52452.44,
#    Period('2015-02', 'M'): 62890.31,
#    Period('2015-04', 'M'): 102796.62,
#    Period('2015-06', 'M'): 13421.12,
#    Period('2015-08', 'M'): 24980.870000000003,
#    Period('2015-09', 'M'): 11559.75,
#    Period('2015-10', 'M'): 11559.75,
#    Period('2015-12', 'M'): 41224.130000000005},
#   'monthly_paid': {Period('2015-01', 'M'): 41670.12,
#    Period('2015-05', 'M'): 218139.37,
#    Period('2015-10', 'M'): 13421.12,
#    Period('2015-11', 'M'): 13421.12,
#    Period('2015-12', 'M'): 11559.75,
#    Period('2016-06', 'M'): 35915.27,
#    Period('2017-12', 'M'): 13596.17},
#   'payment_status_breakdown': {'Fully Paid': 10, 'Partially Paid': 2}},
#  '26': {'total_invoices': 14,
#   'total_invoiced': 559764.4100000001,
#   'total_paid': 531031.75,
#   'average_days_to_pay': 90.78571428571429,
#   'late_invoices_count': 14,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 28732.660000000003,
#   'monthly_invoiced': {Period('2015-09', 'M'): 43149.21,
#    Period('2015-10', 'M'): 91350.75,
#    Period('2015-11', 'M'): 80710.38,
#    Period('2015-12', 'M'): 160246.64,
#    Period('2016-02', 'M'): 14868.0,
#    Period('2016-03', 'M'): 28982.12,
#    Period('2016-05', 'M'): 7121.77,
#    Period('2016-06', 'M'): 95712.66,
#    Period('2016-07', 'M'): 7121.77,
#    Period('2016-10', 'M'): 7121.77,
#    Period('2016-11', 'M'): 23379.34},
#   'monthly_paid': {Period('2015-11', 'M'): 134499.96,
#    Period('2015-12', 'M'): 80710.38,
#    Period('2016-04', 'M'): 204096.76,
#    Period('2016-07', 'M'): 28519.92,
#    Period('2016-09', 'M'): 7121.77,
#    Period('2017-01', 'M'): 45581.85,
#    Period('2017-05', 'M'): 7121.77,
#    Period('2017-06', 'M'): 23379.34},
#   'payment_status_breakdown': {'Fully Paid': 12, 'Partially Paid': 2}},
#  '27': {'total_invoices': 1,
#   'total_invoiced': 59922.56,
#   'total_paid': 59922.56,
#   'average_days_to_pay': 4.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2024-02', 'M'): 59922.56},
#   'monthly_paid': {Period('2024-02', 'M'): 59922.56},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '28': {'total_invoices': 2,
#   'total_invoiced': 54407.340000000004,
#   'total_paid': 54407.340000000004,
#   'average_days_to_pay': 178.0,
#   'late_invoices_count': 2,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2022-02', 'M'): 54407.340000000004},
#   'monthly_paid': {Period('2022-08', 'M'): 54407.340000000004},
#   'payment_status_breakdown': {'Fully Paid': 2}},
#  '29': {'total_invoices': 32,
#   'total_invoiced': 5167932.4,
#   'total_paid': 4546957.12,
#   'average_days_to_pay': 97.59375,
#   'late_invoices_count': 18,
#   'late_invoices_percentage': 56.25,
#   'outstanding_invoices': 3,
#   'outstanding_amount': 620975.28,
#   'monthly_invoiced': {Period('2017-10', 'M'): 602635.53,
#    Period('2017-11', 'M'): 666462.61,
#    Period('2017-12', 'M'): 1035045.36,
#    Period('2018-01', 'M'): 852526.52,
#    Period('2018-03', 'M'): 1487927.3800000001,
#    Period('2018-04', 'M'): 38791.08,
#    Period('2018-05', 'M'): 244591.94,
#    Period('2018-06', 'M'): 177454.82,
#    Period('2018-08', 'M'): 21400.91,
#    Period('2018-10', 'M'): 41096.25},
#   'monthly_paid': {Period('2017-10', 'M'): 226628.14,
#    Period('2017-11', 'M'): 376007.39,
#    Period('2017-12', 'M'): 666462.61,
#    Period('2018-01', 'M'): 1035045.36,
#    Period('2018-04', 'M'): 866952.1,
#    Period('2018-09', 'M'): 621935.45,
#    Period('2018-10', 'M'): 282.26,
#    Period('2018-11', 'M'): 712547.5599999999,
#    Period('2019-03', 'M'): 41096.25},
#   'payment_status_breakdown': {'Fully Paid': 29, 'Partially Paid': 3}},
#  '30': {'total_invoices': 3,
#   'total_invoiced': 424386.25,
#   'total_paid': 424386.25,
#   'average_days_to_pay': 95.66666666666667,
#   'late_invoices_count': 3,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2022-06', 'M'): 222032.13,
#    Period('2022-09', 'M'): 101177.06,
#    Period('2022-12', 'M'): 101177.06},
#   'monthly_paid': {Period('2022-09', 'M'): 222032.13,
#    Period('2022-11', 'M'): 101177.06,
#    Period('2023-05', 'M'): 101177.06},
#   'payment_status_breakdown': {'Fully Paid': 3}},
#  '31': {'total_invoices': 1,
#   'total_invoiced': 59632.58,
#   'total_paid': 59632.58,
#   'average_days_to_pay': 7.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2023-09', 'M'): 59632.58},
#   'monthly_paid': {Period('2023-09', 'M'): 59632.58},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '32': {'total_invoices': 3,
#   'total_invoiced': 268520.05,
#   'total_paid': 58384.66,
#   'average_days_to_pay': 941.0,
#   'late_invoices_count': 3,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 210135.38999999998,
#   'monthly_invoiced': {Period('2013-03', 'M'): 268520.05},
#   'monthly_paid': {Period('2015-10', 'M'): 58384.66},
#   'payment_status_breakdown': {'Partially Paid': 2, 'Fully Paid': 1}},
#  '33': {'total_invoices': 25,
#   'total_invoiced': 5477097.92,
#   'total_paid': 4438577.140000001,
#   'average_days_to_pay': 123.36,
#   'late_invoices_count': 25,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 7,
#   'outstanding_amount': 1038520.78,
#   'monthly_invoiced': {Period('2022-01', 'M'): 586174.35,
#    Period('2022-02', 'M'): 1308611.76,
#    Period('2022-08', 'M'): 1628641.0999999999,
#    Period('2022-11', 'M'): 161787.54,
#    Period('2023-04', 'M'): 10855.01,
#    Period('2023-06', 'M'): 1759713.27,
#    Period('2023-09', 'M'): 21314.89},
#   'monthly_paid': {Period('2022-03', 'M'): 483442.19,
#    Period('2022-05', 'M'): 1249159.6,
#    Period('2022-11', 'M'): 1110723.16,
#    Period('2023-03', 'M'): 161787.54,
#    Period('2023-06', 'M'): 31404.88,
#    Period('2023-08', 'M'): 1380744.88,
#    Period('2024-01', 'M'): 21314.89},
#   'payment_status_breakdown': {'Fully Paid': 18, 'Partially Paid': 7}},
#  '34': {'total_invoices': 46,
#   'total_invoiced': 4816628.16,
#   'total_paid': 2381490.1,
#   'average_days_to_pay': 160.2391304347826,
#   'late_invoices_count': 30,
#   'late_invoices_percentage': 65.21739130434783,
#   'outstanding_invoices': 37,
#   'outstanding_amount': 2435138.0600000005,
#   'monthly_invoiced': {Period('2014-12', 'M'): 109036.88,
#    Period('2015-02', 'M'): 235737.1,
#    Period('2015-04', 'M'): 369646.26999999996,
#    Period('2015-05', 'M'): 64552.96,
#    Period('2015-06', 'M'): 813643.3200000001,
#    Period('2015-07', 'M'): 268189.54000000004,
#    Period('2015-08', 'M'): 123568.68,
#    Period('2015-09', 'M'): 153958.68,
#    Period('2015-10', 'M'): 1562671.76,
#    Period('2015-11', 'M'): 600340.73,
#    Period('2015-12', 'M'): 457640.02,
#    Period('2017-03', 'M'): 57642.22},
#   'monthly_paid': {Period('2015-02', 'M'): 54518.44,
#    Period('2015-05', 'M'): 231216.47,
#    Period('2015-06', 'M'): 117868.55,
#    Period('2015-08', 'M'): 12736.300000000001,
#    Period('2015-09', 'M'): 32276.48,
#    Period('2015-10', 'M'): 670215.58,
#    Period('2015-12', 'M'): 76979.34,
#    Period('2016-02', 'M'): 254483.01,
#    Period('2016-08', 'M'): 403156.16000000003,
#    Period('2017-04', 'M'): 327742.5,
#    Period('2018-10', 'M'): 200297.27000000002},
#   'payment_status_breakdown': {'Partially Paid': 37, 'Fully Paid': 9}},
#  '35': {'total_invoices': 10,
#   'total_invoiced': 812701.43,
#   'total_paid': 492072.01,
#   'average_days_to_pay': 2112.8,
#   'late_invoices_count': 10,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 320629.42,
#   'monthly_invoiced': {Period('2010-04', 'M'): 53598.84,
#    Period('2011-03', 'M'): 16111.23,
#    Period('2011-04', 'M'): 280584.99,
#    Period('2012-02', 'M'): 16473.16,
#    Period('2012-03', 'M'): 16473.16,
#    Period('2014-02', 'M'): 118963.34,
#    Period('2014-06', 'M'): 81008.46,
#    Period('2014-07', 'M'): 107074.02,
#    Period('2014-08', 'M'): 107074.02,
#    Period('2015-05', 'M'): 15340.21},
#   'monthly_paid': {Period('2015-03', 'M'): 107074.02,
#    Period('2019-03', 'M'): 384997.99},
#   'payment_status_breakdown': {'Fully Paid': 8, 'Partially Paid': 2}},
#  '36': {'total_invoices': 24,
#   'total_invoiced': 503506.63,
#   'total_paid': 472118.96,
#   'average_days_to_pay': 312.7083333333333,
#   'late_invoices_count': 24,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 1,
#   'outstanding_amount': 31387.670000000002,
#   'monthly_invoiced': {Period('2014-03', 'M'): 60028.91,
#    Period('2014-05', 'M'): 29943.04,
#    Period('2014-06', 'M'): 127423.42000000001,
#    Period('2014-07', 'M'): 78553.37,
#    Period('2014-08', 'M'): 14971.52,
#    Period('2014-09', 'M'): 14971.52,
#    Period('2014-10', 'M'): 14971.52,
#    Period('2014-11', 'M'): 29943.04,
#    Period('2014-12', 'M'): 29943.04,
#    Period('2015-01', 'M'): 14971.52,
#    Period('2015-02', 'M'): 14971.52,
#    Period('2015-06', 'M'): 15015.46,
#    Period('2015-08', 'M'): 11559.75,
#    Period('2015-09', 'M'): 11559.75,
#    Period('2015-10', 'M'): 11559.75,
#    Period('2015-11', 'M'): 11559.75,
#    Period('2015-12', 'M'): 11559.75},
#   'monthly_paid': {Period('2015-01', 'M'): 140627.22,
#    Period('2015-03', 'M'): 89829.12,
#    Period('2015-10', 'M'): 26575.21,
#    Period('2015-12', 'M'): 79019.29000000001,
#    Period('2016-04', 'M'): 89829.12,
#    Period('2016-09', 'M'): 46239.0},
#   'payment_status_breakdown': {'Fully Paid': 23, 'Partially Paid': 1}},
#  '37': {'total_invoices': 112,
#   'total_invoiced': 14133137.34,
#   'total_paid': 9590771.66,
#   'average_days_to_pay': 65.49107142857143,
#   'late_invoices_count': 86,
#   'late_invoices_percentage': 76.78571428571429,
#   'outstanding_invoices': 44,
#   'outstanding_amount': 4542365.68,
#   'monthly_invoiced': {Period('2016-01', 'M'): 491755.74,
#    Period('2016-02', 'M'): 18137.15,
#    Period('2016-03', 'M'): 983775.27,
#    Period('2016-04', 'M'): 627254.61,
#    Period('2016-05', 'M'): 545305.9,
#    Period('2016-06', 'M'): 213303.84,
#    Period('2016-07', 'M'): 2079665.6,
#    Period('2017-05', 'M'): 613941.41,
#    Period('2017-06', 'M'): 219444.88,
#    Period('2017-07', 'M'): 195910.08,
#    Period('2017-08', 'M'): 1356868.34,
#    Period('2017-09', 'M'): 602407.2,
#    Period('2017-10', 'M'): 63833.38,
#    Period('2017-11', 'M'): 763741.32,
#    Period('2018-01', 'M'): 2114802.9,
#    Period('2018-02', 'M'): 1315737.66,
#    Period('2018-03', 'M'): 173535.79,
#    Period('2018-04', 'M'): 607313.77,
#    Period('2018-05', 'M'): 88591.72,
#    Period('2018-06', 'M'): 29209.46,
#    Period('2018-07', 'M'): 5339.71,
#    Period('2018-08', 'M'): 343807.92,
#    Period('2018-10', 'M'): 16473.16,
#    Period('2018-12', 'M'): 60878.34,
#    Period('2019-01', 'M'): 58524.95,
#    Period('2019-02', 'M'): 58524.95,
#    Period('2019-05', 'M'): 15728.41,
#    Period('2019-06', 'M'): 57749.08,
#    Period('2019-07', 'M'): 104116.3,
#    Period('2019-08', 'M'): 48004.89,
#    Period('2019-09', 'M'): 57788.479999999996,
#    Period('2019-10', 'M'): 102166.94,
#    Period('2019-11', 'M'): 99498.19},
#   'monthly_paid': {Period('2016-02', 'M'): 491755.74,
#    Period('2016-03', 'M'): 18137.15,
#    Period('2016-05', 'M'): 955179.7,
#    Period('2016-07', 'M'): 758609.74,
#    Period('2016-09', 'M'): 632778.13,
#    Period('2017-01', 'M'): 87271.86,
#    Period('2017-05', 'M'): 26498.38,
#    Period('2017-06', 'M'): 437176.89,
#    Period('2017-07', 'M'): 154891.91999999998,
#    Period('2017-09', 'M'): 81037.57,
#    Period('2017-10', 'M'): 283757.12,
#    Period('2017-11', 'M'): 244555.54,
#    Period('2017-12', 'M'): 456644.57999999996,
#    Period('2018-02', 'M'): 1359430.29,
#    Period('2018-03', 'M'): 661125.44,
#    Period('2018-04', 'M'): 1093447.72,
#    Period('2018-06', 'M'): 660920.58,
#    Period('2018-07', 'M'): 88591.72,
#    Period('2018-08', 'M'): 113666.85,
#    Period('2018-09', 'M'): 373017.38,
#    Period('2018-11', 'M'): 29254.85,
#    Period('2019-03', 'M'): 60878.34,
#    Period('2019-07', 'M'): 177791.1,
#    Period('2019-10', 'M'): 152121.19,
#    Period('2019-11', 'M'): 57788.479999999996,
#    Period('2019-12', 'M'): 49749.09,
#    Period('2020-01', 'M'): 40066.14,
#    Period('2020-02', 'M'): 44628.170000000006},
#   'payment_status_breakdown': {'Fully Paid': 68, 'Partially Paid': 44}},
#  '38': {'total_invoices': 32,
#   'total_invoiced': 1080202.32,
#   'total_paid': 930010.15,
#   'average_days_to_pay': 94.75,
#   'late_invoices_count': 29,
#   'late_invoices_percentage': 90.625,
#   'outstanding_invoices': 12,
#   'outstanding_amount': 150192.16999999998,
#   'monthly_invoiced': {Period('2017-12', 'M'): 65458.21000000001,
#    Period('2018-02', 'M'): 284600.22,
#    Period('2018-03', 'M'): 191476.31,
#    Period('2018-04', 'M'): 10293.87,
#    Period('2018-05', 'M'): 15483.650000000001,
#    Period('2018-07', 'M'): 20918.19,
#    Period('2018-10', 'M'): 70268.12,
#    Period('2018-11', 'M'): 41486.85,
#    Period('2019-05', 'M'): 96133.3,
#    Period('2019-07', 'M'): 52452.44,
#    Period('2019-08', 'M'): 5189.78,
#    Period('2019-09', 'M'): 125882.59,
#    Period('2019-10', 'M'): 33363.89,
#    Period('2019-12', 'M'): 67194.9},
#   'monthly_paid': {Period('2018-01', 'M'): 65458.21000000001,
#    Period('2018-04', 'M'): 180246.80000000002,
#    Period('2018-05', 'M'): 147168.22,
#    Period('2018-07', 'M'): 15483.650000000001,
#    Period('2018-08', 'M'): 14447.16,
#    Period('2018-09', 'M'): 31212.06,
#    Period('2018-12', 'M'): 15728.41,
#    Period('2019-01', 'M'): 41486.85,
#    Period('2019-02', 'M'): 7131.37,
#    Period('2019-09', 'M'): 180839.91,
#    Period('2019-10', 'M'): 82169.12,
#    Period('2019-12', 'M'): 54093.03,
#    Period('2020-01', 'M'): 78895.85,
#    Period('2021-05', 'M'): 15649.51},
#   'payment_status_breakdown': {'Fully Paid': 20, 'Partially Paid': 12}},
#  '39': {'total_invoices': 5,
#   'total_invoiced': 632915.68,
#   'total_paid': 632915.68,
#   'average_days_to_pay': 75.6,
#   'late_invoices_count': 3,
#   'late_invoices_percentage': 60.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2023-01', 'M'): 82850.72,
#    Period('2023-02', 'M'): 200230.3,
#    Period('2023-07', 'M'): 200230.3,
#    Period('2023-10', 'M'): 149604.36},
#   'monthly_paid': {Period('2023-02', 'M'): 82850.72,
#    Period('2023-08', 'M'): 200230.3,
#    Period('2023-11', 'M'): 200230.3,
#    Period('2023-12', 'M'): 149604.36},
#   'payment_status_breakdown': {'Fully Paid': 5}},
#  '40': {'total_invoices': 22,
#   'total_invoiced': 5419136.27,
#   'total_paid': 5419136.27,
#   'average_days_to_pay': 42.45454545454545,
#   'late_invoices_count': 12,
#   'late_invoices_percentage': 54.54545454545454,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2023-08', 'M'): 30099.63,
#    Period('2023-11', 'M'): 615444.39,
#    Period('2023-12', 'M'): 2091373.37,
#    Period('2024-02', 'M'): 2682218.88},
#   'monthly_paid': {Period('2023-10', 'M'): 30099.63,
#    Period('2024-01', 'M'): 615444.39,
#    Period('2024-02', 'M'): 2091373.37,
#    Period('2024-03', 'M'): 2682218.88},
#   'payment_status_breakdown': {'Fully Paid': 22}},
#  '41': {'total_invoices': 44,
#   'total_invoiced': 2475416.6499999994,
#   'total_paid': 2420898.1999999993,
#   'average_days_to_pay': 144.1590909090909,
#   'late_invoices_count': 38,
#   'late_invoices_percentage': 86.36363636363636,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 54518.450000000004,
#   'monthly_invoiced': {Period('2015-01', 'M'): 81008.46,
#    Period('2015-05', 'M'): 243595.69,
#    Period('2015-06', 'M'): 474807.88,
#    Period('2015-07', 'M'): 271243.86,
#    Period('2015-08', 'M'): 201982.68,
#    Period('2015-09', 'M'): 194396.14,
#    Period('2015-10', 'M'): 81008.46,
#    Period('2015-11', 'M'): 81008.46,
#    Period('2016-07', 'M'): 69302.74,
#    Period('2016-09', 'M'): 170294.08000000002,
#    Period('2016-10', 'M'): 226956.55000000002,
#    Period('2016-11', 'M'): 126463.94,
#    Period('2017-02', 'M'): 85126.26,
#    Period('2022-04', 'M'): 25512.0,
#    Period('2022-10', 'M'): 142709.45},
#   'monthly_paid': {Period('2015-05', 'M'): 324604.15,
#    Period('2015-08', 'M'): 186117.6,
#    Period('2015-11', 'M'): 449443.43,
#    Period('2016-02', 'M'): 81008.46,
#    Period('2016-04', 'M'): 452351.08,
#    Period('2016-08', 'M'): 81008.46,
#    Period('2016-10', 'M'): 69302.74,
#    Period('2017-01', 'M'): 154429.0,
#    Period('2017-03', 'M'): 167302.89,
#    Period('2017-04', 'M'): 100991.34,
#    Period('2017-06', 'M'): 85126.26,
#    Period('2019-03', 'M'): 100991.34,
#    Period('2022-11', 'M'): 25512.0,
#    Period('2022-12', 'M'): 142709.45},
#   'payment_status_breakdown': {'Fully Paid': 42, 'Partially Paid': 2}},
#  '42': {'total_invoices': 4,
#   'total_invoiced': 467636.24,
#   'total_paid': 350727.18,
#   'average_days_to_pay': 34.25,
#   'late_invoices_count': 2,
#   'late_invoices_percentage': 50.0,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 116909.06,
#   'monthly_invoiced': {Period('2022-06', 'M'): 350727.18,
#    Period('2022-08', 'M'): 116909.06},
#   'monthly_paid': {Period('2022-07', 'M'): 116909.06,
#    Period('2022-08', 'M'): 175363.59,
#    Period('2022-09', 'M'): 58454.53},
#   'payment_status_breakdown': {'Partially Paid': 2, 'Fully Paid': 2}},
#  '43': {'total_invoices': 74,
#   'total_invoiced': 2071034.41,
#   'total_paid': 1955408.4100000001,
#   'average_days_to_pay': 139.01351351351352,
#   'late_invoices_count': 50,
#   'late_invoices_percentage': 67.56756756756756,
#   'outstanding_invoices': 8,
#   'outstanding_amount': 115626.0,
#   'monthly_invoiced': {Period('2015-06', 'M'): 47795.69,
#    Period('2015-08', 'M'): 134124.11,
#    Period('2016-11', 'M'): 15557.24,
#    Period('2016-12', 'M'): 27707.82,
#    Period('2017-01', 'M'): 27707.82,
#    Period('2017-02', 'M'): 27707.82,
#    Period('2018-09', 'M'): 17435.27,
#    Period('2018-11', 'M'): 17774.53,
#    Period('2018-12', 'M'): 17774.53,
#    Period('2019-01', 'M'): 17774.53,
#    Period('2019-02', 'M'): 17774.53,
#    Period('2019-03', 'M'): 17774.53,
#    Period('2019-04', 'M'): 342456.45,
#    Period('2019-05', 'M'): 216229.75,
#    Period('2019-06', 'M'): 117111.60999999999,
#    Period('2019-07', 'M'): 17774.53,
#    Period('2019-08', 'M'): 77052.29999999999,
#    Period('2019-09', 'M'): 118539.15,
#    Period('2019-10', 'M'): 53356.369999999995,
#    Period('2019-11', 'M'): 123017.32999999999,
#    Period('2019-12', 'M'): 63739.56,
#    Period('2022-01', 'M'): 40606.2,
#    Period('2022-02', 'M'): 28174.11,
#    Period('2022-03', 'M'): 68780.31,
#    Period('2022-04', 'M'): 28174.11,
#    Period('2022-05', 'M'): 40606.2,
#    Period('2022-06', 'M'): 43189.57,
#    Period('2022-08', 'M'): 95405.79,
#    Period('2022-09', 'M'): 28174.11,
#    Period('2022-10', 'M'): 41594.55,
#    Period('2022-11', 'M'): 68780.31,
#    Period('2022-12', 'M'): 28174.11,
#    Period('2023-01', 'M'): 28174.11,
#    Period('2023-08', 'M'): 15015.46},
#   'monthly_paid': {Period('2015-06', 'M'): 47795.69,
#    Period('2015-09', 'M'): 134124.11,
#    Period('2016-12', 'M'): 15557.24,
#    Period('2017-01', 'M'): 27707.82,
#    Period('2018-09', 'M'): 17435.27,
#    Period('2018-12', 'M'): 73190.17,
#    Period('2019-01', 'M'): 17774.53,
#    Period('2019-02', 'M'): 17774.53,
#    Period('2019-03', 'M'): 17774.53,
#    Period('2019-05', 'M'): 17774.53,
#    Period('2019-06', 'M'): 35565.45,
#    Period('2019-08', 'M'): 106696.34999999999,
#    Period('2019-09', 'M'): 687640.61,
#    Period('2019-11', 'M'): 77052.3,
#    Period('2019-12', 'M'): 77052.29999999999,
#    Period('2020-01', 'M'): 63739.56,
#    Period('2020-02', 'M'): 63739.56,
#    Period('2022-05', 'M'): 79736.91,
#    Period('2022-10', 'M'): 84522.33,
#    Period('2022-11', 'M'): 41594.55,
#    Period('2022-12', 'M'): 50393.02,
#    Period('2023-06', 'M'): 82268.51999999999,
#    Period('2023-08', 'M'): 15015.46,
#    Period('2024-02', 'M'): 103483.07},
#   'payment_status_breakdown': {'Fully Paid': 66, 'Partially Paid': 8}},
#  '44': {'total_invoices': 10,
#   'total_invoiced': 352088.89999999997,
#   'total_paid': 352088.89999999997,
#   'average_days_to_pay': 111.7,
#   'late_invoices_count': 8,
#   'late_invoices_percentage': 80.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2022-06', 'M'): 49013.56,
#    Period('2022-07', 'M'): 25512.0,
#    Period('2022-08', 'M'): 115607.7,
#    Period('2023-03', 'M'): 106075.73,
#    Period('2023-05', 'M'): 5497.8,
#    Period('2023-08', 'M'): 15015.46,
#    Period('2023-09', 'M'): 17435.27,
#    Period('2023-11', 'M'): 17931.38},
#   'monthly_paid': {Period('2022-09', 'M'): 57090.29,
#    Period('2023-01', 'M'): 55685.14,
#    Period('2023-03', 'M'): 59922.56,
#    Period('2023-04', 'M'): 106075.73,
#    Period('2023-08', 'M'): 32450.73,
#    Period('2023-09', 'M'): 5497.8,
#    Period('2023-11', 'M'): 17435.27,
#    Period('2024-02', 'M'): 17931.38},
#   'payment_status_breakdown': {'Fully Paid': 10}},
#  '45': {'total_invoices': 14,
#   'total_invoiced': 268862.12,
#   'total_paid': 268862.12,
#   'average_days_to_pay': 28.214285714285715,
#   'late_invoices_count': 9,
#   'late_invoices_percentage': 64.28571428571429,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2015-05', 'M'): 39465.34,
#    Period('2016-06', 'M'): 89208.0,
#    Period('2016-08', 'M'): 64222.34,
#    Period('2016-09', 'M'): 14868.0,
#    Period('2019-03', 'M'): 61098.44},
#   'monthly_paid': {Period('2015-05', 'M'): 39465.34,
#    Period('2016-08', 'M'): 123694.34,
#    Period('2016-11', 'M'): 44604.0,
#    Period('2019-03', 'M'): 61098.44},
#   'payment_status_breakdown': {'Fully Paid': 14}},
#  '46': {'total_invoices': 5,
#   'total_invoiced': 526256.65,
#   'total_paid': 210502.66000000003,
#   'average_days_to_pay': 132.6,
#   'late_invoices_count': 5,
#   'late_invoices_percentage': 100.0,
# ...
#    Period('2015-10', 'M'): 121661.69,
#    Period('2016-09', 'M'): 113128.64000000001,
#    Period('2017-02', 'M'): 20225.4,
#    Period('2017-03', 'M'): 20225.4},
#   'payment_status_breakdown': {'Fully Paid': 7, 'Partially Paid': 1}},
#  '263': {'total_invoices': 12,
#   'total_invoiced': 2048237.2999999998,
#   'total_paid': 878764.44,
#   'average_days_to_pay': 125.91666666666667,
#   'late_invoices_count': 9,
#   'late_invoices_percentage': 75.0,
#   'outstanding_invoices': 11,
#   'outstanding_amount': 1169472.86,
#   'monthly_invoiced': {Period('2015-02', 'M'): 416986.88,
#    Period('2015-05', 'M'): 501440.43,
#    Period('2015-06', 'M'): 1129809.99},
#   'monthly_paid': {Period('2015-02', 'M'): 91866.36,
#    Period('2015-04', 'M'): 116627.08,
#    Period('2015-05', 'M'): 1152.74,
#    Period('2015-07', 'M'): 372431.76,
#    Period('2016-12', 'M'): 296686.5},
#   'payment_status_breakdown': {'Partially Paid': 11, 'Fully Paid': 1}},
#  '264': {'total_invoices': 31,
#   'total_invoiced': 2513348.0700000003,
#   'total_paid': 1805839.6000000003,
#   'average_days_to_pay': 85.7741935483871,
#   'late_invoices_count': 31,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 10,
#   'outstanding_amount': 707508.4700000001,
#   'monthly_invoiced': {Period('2014-10', 'M'): 44926.38,
#    Period('2014-11', 'M'): 247178.33,
#    Period('2014-12', 'M'): 101965.07,
#    Period('2015-01', 'M'): 133090.45,
#    Period('2015-02', 'M'): 26345.62,
#    Period('2015-03', 'M'): 94115.75,
#    Period('2015-04', 'M'): 21757.88,
#    Period('2015-06', 'M'): 12005.81,
#    Period('2016-04', 'M'): 94319.9,
#    Period('2016-05', 'M'): 310169.07999999996,
#    Period('2016-06', 'M'): 585070.3200000001,
#    Period('2016-08', 'M'): 418932.5,
#    Period('2017-05', 'M'): 41670.12,
#    Period('2017-06', 'M'): 91956.92,
#    Period('2017-07', 'M'): 156094.44,
#    Period('2017-08', 'M'): 133749.5},
#   'monthly_paid': {Period('2015-01', 'M'): 44926.38,
#    Period('2015-02', 'M'): 122189.22,
#    Period('2015-03', 'M'): 226954.18,
#    Period('2015-04', 'M'): 159436.07,
#    Period('2015-07', 'M'): 115873.63,
#    Period('2015-10', 'M'): 12005.81,
#    Period('2016-05', 'M'): 94319.9,
#    Period('2016-07', 'M'): 168148.9,
#    Period('2016-09', 'M'): 512114.11999999994,
#    Period('2017-08', 'M'): 41670.12,
#    Period('2017-10', 'M'): 78507.26,
#    Period('2017-11', 'M'): 162819.26,
#    Period('2017-12', 'M'): 66874.75},
#   'payment_status_breakdown': {'Fully Paid': 21, 'Partially Paid': 10}},
#  '265': {'total_invoices': 9,
#   'total_invoiced': 571548.51,
#   'total_paid': 571548.51,
#   'average_days_to_pay': 112.88888888888889,
#   'late_invoices_count': 7,
#   'late_invoices_percentage': 77.77777777777779,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2017-03', 'M'): 227066.53,
#    Period('2017-06', 'M'): 79923.51000000001,
#    Period('2017-07', 'M'): 174106.05,
#    Period('2017-08', 'M'): 90452.42},
#   'monthly_paid': {Period('2017-04', 'M'): 227066.53,
#    Period('2017-12', 'M'): 144391.47,
#    Period('2018-02', 'M'): 200090.51},
#   'payment_status_breakdown': {'Fully Paid': 9}},
#  '266': {'total_invoices': 20,
#   'total_invoiced': 1190579.5599999998,
#   'total_paid': 715947.6400000001,
#   'average_days_to_pay': 453.2,
#   'late_invoices_count': 20,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 14,
#   'outstanding_amount': 474631.92000000004,
#   'monthly_invoiced': {Period('2018-11', 'M'): 293558.26,
#    Period('2019-02', 'M'): 141387.04,
#    Period('2019-04', 'M'): 118137.09,
#    Period('2019-06', 'M'): 97956.11,
#    Period('2019-07', 'M'): 482946.73,
#    Period('2019-09', 'M'): 56594.33},
#   'monthly_paid': {Period('2019-08', 'M'): 599367.36,
#    Period('2020-05', 'M'): 57842.07000000001,
#    Period('2021-02', 'M'): 13931.230000000001,
#    Period('2021-03', 'M'): 7300.78,
#    Period('2021-05', 'M'): 7300.78,
#    Period('2021-06', 'M'): 14601.56,
#    Period('2021-08', 'M'): 6572.4,
#    Period('2021-09', 'M'): 9031.46},
#   'payment_status_breakdown': {'Partially Paid': 14, 'Fully Paid': 6}},
#  '267': {'total_invoices': 28,
#   'total_invoiced': 1205170.92,
#   'total_paid': 1143478.95,
#   'average_days_to_pay': 78.07142857142857,
#   'late_invoices_count': 25,
#   'late_invoices_percentage': 89.28571428571429,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 61691.97,
#   'monthly_invoiced': {Period('2015-10', 'M'): 232558.63,
#    Period('2015-11', 'M'): 136520.04,
#    Period('2015-12', 'M'): 39081.0,
#    Period('2016-01', 'M'): 134622.82,
#    Period('2016-02', 'M'): 73547.41,
#    Period('2016-03', 'M'): 32447.16,
#    Period('2017-10', 'M'): 24900.41,
#    Period('2017-11', 'M'): 123383.92,
#    Period('2018-02', 'M'): 37215.229999999996,
#    Period('2018-05', 'M'): 14990.88,
#    Period('2018-08', 'M'): 13420.44,
#    Period('2018-09', 'M'): 13420.44,
#    Period('2018-10', 'M'): 13420.44,
#    Period('2019-01', 'M'): 63755.24,
#    Period('2019-02', 'M'): 63755.24,
#    Period('2019-03', 'M'): 13420.44,
#    Period('2019-04', 'M'): 29925.97,
#    Period('2019-05', 'M'): 29925.97,
#    Period('2019-06', 'M'): 81722.64,
#    Period('2019-08', 'M'): 33136.6},
#   'monthly_paid': {Period('2015-10', 'M'): 179710.91,
#    Period('2015-12', 'M'): 189367.76,
#    Period('2016-03', 'M'): 247251.23,
#    Period('2016-05', 'M'): 32447.16,
#    Period('2018-03', 'M'): 60440.34,
#    Period('2018-05', 'M'): 63367.25,
#    Period('2018-09', 'M'): 14990.88,
#    Period('2019-01', 'M'): 40261.32,
#    Period('2019-04', 'M'): 63755.24,
#    Period('2019-07', 'M'): 137027.62,
#    Period('2019-10', 'M'): 114859.24},
#   'payment_status_breakdown': {'Fully Paid': 26, 'Partially Paid': 2}},
#  '268': {'total_invoices': 6,
#   'total_invoiced': 190592.26,
#   'total_paid': 190592.26,
#   'average_days_to_pay': 135.66666666666666,
#   'late_invoices_count': 6,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2015-11', 'M'): 10758.14,
#    Period('2015-12', 'M'): 106690.5,
#    Period('2016-03', 'M'): 73143.62},
#   'monthly_paid': {Period('2016-01', 'M'): 10758.14,
#    Period('2016-07', 'M'): 179834.12},
#   'payment_status_breakdown': {'Fully Paid': 6}},
#  '269': {'total_invoices': 14,
#   'total_invoiced': 2828542.0900000003,
#   'total_paid': 2528354.2399999998,
#   'average_days_to_pay': 96.14285714285714,
#   'late_invoices_count': 13,
#   'late_invoices_percentage': 92.85714285714286,
#   'outstanding_invoices': 5,
#   'outstanding_amount': 300187.85,
#   'monthly_invoiced': {Period('2019-05', 'M'): 662465.78,
#    Period('2019-06', 'M'): 275319.5,
#    Period('2019-07', 'M'): 395696.93,
#    Period('2019-08', 'M'): 874084.6000000001,
#    Period('2019-10', 'M'): 620975.28},
#   'monthly_paid': {Period('2019-07', 'M'): 472969.5,
#    Period('2019-08', 'M'): 996996.9900000001,
#    Period('2019-10', 'M'): 82096.69,
#    Period('2020-01', 'M'): 652111.86,
#    Period('2020-02', 'M'): 33145.19,
#    Period('2020-05', 'M'): 291034.01},
#   'payment_status_breakdown': {'Fully Paid': 9, 'Partially Paid': 5}},
#  '270': {'total_invoices': 5,
#   'total_invoiced': 35730.64,
#   'total_paid': 35730.64,
#   'average_days_to_pay': 11.2,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2015-05', 'M'): 14971.52,
#    Period('2015-06', 'M'): 5189.78,
#    Period('2015-07', 'M'): 5189.78,
#    Period('2015-08', 'M'): 5189.78,
#    Period('2015-09', 'M'): 5189.78},
#   'monthly_paid': {Period('2015-06', 'M'): 14971.52,
#    Period('2015-07', 'M'): 5189.78,
#    Period('2015-08', 'M'): 5189.78,
#    Period('2015-09', 'M'): 5189.78,
#    Period('2015-10', 'M'): 5189.78},
#   'payment_status_breakdown': {'Fully Paid': 5}},
#  '271': {'total_invoices': 18,
#   'total_invoiced': 330489.51999999996,
#   'total_paid': 330489.51999999996,
#   'average_days_to_pay': 145.77777777777777,
#   'late_invoices_count': 18,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2014-08', 'M'): 31232.84,
#    Period('2014-09', 'M'): 31232.84,
#    Period('2014-12', 'M'): 76979.34,
#    Period('2015-01', 'M'): 12736.3,
#    Period('2015-02', 'M'): 12736.3,
#    Period('2015-03', 'M'): 12736.3,
#    Period('2015-04', 'M'): 12736.3,
#    Period('2015-05', 'M'): 12736.3,
#    Period('2015-06', 'M'): 12736.3,
#    Period('2015-07', 'M'): 12736.3,
#    Period('2015-08', 'M'): 12736.3,
#    Period('2015-09', 'M'): 12736.3,
#    Period('2015-10', 'M'): 12736.3,
#    Period('2015-11', 'M'): 12736.3,
#    Period('2015-12', 'M'): 12736.3,
#    Period('2016-01', 'M'): 12736.3,
#    Period('2016-02', 'M'): 12736.3,
#    Period('2016-03', 'M'): 12736.3},
#   'monthly_paid': {Period('2015-05', 'M'): 164917.62,
#    Period('2015-07', 'M'): 25472.6,
#    Period('2015-10', 'M'): 38208.899999999994,
#    Period('2015-11', 'M'): 12736.3,
#    Period('2015-12', 'M'): 12736.3,
#    Period('2016-02', 'M'): 12736.3,
#    Period('2016-03', 'M'): 25472.6,
#    Period('2016-06', 'M'): 12736.3,
#    Period('2016-07', 'M'): 12736.3,
#    Period('2017-10', 'M'): 12736.3},
#   'payment_status_breakdown': {'Fully Paid': 18}},
#  '272': {'total_invoices': 6,
#   'total_invoiced': 1370512.86,
#   'total_paid': 456837.63,
#   'average_days_to_pay': 1031.3333333333333,
#   'late_invoices_count': 6,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 6,
#   'outstanding_amount': 913675.2299999999,
#   'monthly_invoiced': {Period('2019-11', 'M'): 1370512.8599999999},
#   'monthly_paid': {Period('2020-03', 'M'): 228418.82,
#    Period('2023-12', 'M'): 228418.81},
#   'payment_status_breakdown': {'Partially Paid': 6}},
#  '273': {'total_invoices': 4,
#   'total_invoiced': 176655.76,
#   'total_paid': 176655.76,
#   'average_days_to_pay': 38.0,
#   'late_invoices_count': 3,
#   'late_invoices_percentage': 75.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2017-02', 'M'): 96814.09,
#    Period('2017-03', 'M'): 26613.89,
#    Period('2017-04', 'M'): 26613.89,
#    Period('2017-05', 'M'): 26613.89},
#   'monthly_paid': {Period('2017-04', 'M'): 96814.09,
#    Period('2017-05', 'M'): 53227.78,
#    Period('2017-07', 'M'): 26613.89},
#   'payment_status_breakdown': {'Fully Paid': 4}},
#  '274': {'total_invoices': 1,
#   'total_invoiced': 105251.33,
#   'total_paid': 105251.33,
#   'average_days_to_pay': 2.0,
#   'late_invoices_count': 0,
#   'late_invoices_percentage': 0.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2016-11', 'M'): 105251.33},
#   'monthly_paid': {Period('2016-11', 'M'): 105251.33},
#   'payment_status_breakdown': {'Fully Paid': 1}},
#  '275': {'total_invoices': 8,
#   'total_invoiced': 394008.93000000005,
#   'total_paid': 346261.17,
#   'average_days_to_pay': 55.375,
#   'late_invoices_count': 5,
#   'late_invoices_percentage': 62.5,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 47747.76000000001,
#   'monthly_invoiced': {Period('2022-05', 'M'): 61287.09,
#    Period('2022-12', 'M'): 61287.09,
#    Period('2023-01', 'M'): 89211.09,
#    Period('2023-02', 'M'): 95495.52,
#    Period('2023-03', 'M'): 16011.57,
#    Period('2023-04', 'M'): 54705.0,
#    Period('2023-09', 'M'): 16011.57},
#   'monthly_paid': {Period('2022-12', 'M'): 122574.18,
#    Period('2023-02', 'M'): 89211.09,
#    Period('2023-04', 'M'): 47747.759999999995,
#    Period('2023-06', 'M'): 70716.57,
#    Period('2023-10', 'M'): 16011.57},
#   'payment_status_breakdown': {'Fully Paid': 6, 'Partially Paid': 2}},
#  '276': {'total_invoices': 11,
#   'total_invoiced': 477957.06,
#   'total_paid': 463089.07,
#   'average_days_to_pay': 60.63636363636363,
#   'late_invoices_count': 9,
#   'late_invoices_percentage': 81.81818181818183,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 14867.99,
#   'monthly_invoiced': {Period('2014-12', 'M'): 42297.66,
#    Period('2015-01', 'M'): 88999.5,
#    Period('2015-02', 'M'): 17617.1,
#    Period('2015-03', 'M'): 104569.93000000001,
#    Period('2015-05', 'M'): 179868.87000000002,
#    Period('2015-06', 'M'): 29736.0,
#    Period('2015-12', 'M'): 14868.0},
#   'monthly_paid': {Period('2015-02', 'M'): 131297.16,
#    Period('2015-03', 'M'): 17617.1,
#    Period('2015-05', 'M'): 104569.93000000001,
#    Period('2015-07', 'M'): 179868.87000000002,
#    Period('2015-11', 'M'): 14868.01,
#    Period('2016-04', 'M'): 14868.0},
#   'payment_status_breakdown': {'Fully Paid': 9, 'Partially Paid': 2}},
#  '277': {'total_invoices': 2,
#   'total_invoiced': 133136.94,
#   'total_paid': 133136.94,
#   'average_days_to_pay': 45.5,
#   'late_invoices_count': 1,
#   'late_invoices_percentage': 50.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2016-01', 'M'): 27885.61,
#    Period('2016-03', 'M'): 105251.33},
#   'monthly_paid': {Period('2016-02', 'M'): 27885.61,
#    Period('2016-06', 'M'): 105251.33},
#   'payment_status_breakdown': {'Fully Paid': 2}},
#  '278': {'total_invoices': 9,
#   'total_invoiced': 134743.68,
#   'total_paid': 119772.16,
#   'average_days_to_pay': 756.7777777777778,
#   'late_invoices_count': 9,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 2,
#   'outstanding_amount': 14971.52,
#   'monthly_invoiced': {Period('2014-08', 'M'): 14971.52,
#    Period('2014-09', 'M'): 14971.52,
#    Period('2014-10', 'M'): 14971.52,
#    Period('2014-11', 'M'): 14971.52,
#    Period('2014-12', 'M'): 14971.52,
#    Period('2015-01', 'M'): 29943.04,
#    Period('2015-02', 'M'): 14971.52,
#    Period('2015-03', 'M'): 14971.52},
#   'monthly_paid': {Period('2015-02', 'M'): 59886.08,
#    Period('2015-11', 'M'): 11602.93,
#    Period('2019-03', 'M'): 48283.15},
#   'payment_status_breakdown': {'Fully Paid': 7, 'Partially Paid': 2}},
#  '279': {'total_invoices': 4,
#   'total_invoiced': 685013.24,
#   'total_paid': 685013.24,
#   'average_days_to_pay': 473.0,
#   'late_invoices_count': 4,
#   'late_invoices_percentage': 100.0,
#   'outstanding_invoices': 0,
#   'outstanding_amount': 0.0,
#   'monthly_invoiced': {Period('2022-09', 'M'): 685013.24},
#   'monthly_paid': {Period('2023-12', 'M'): 685013.24},
#   'payment_status_breakdown': {'Fully Paid': 4}},
#  '280': {'total_invoices': 4,
#   'total_invoiced': 419138.86,
#   'total_paid': 209569.44,
#   'average_days_to_pay': 190.0,
#   'late_invoices_count': 2,
#   'late_invoices_percentage': 50.0,
#   'outstanding_invoices': 4,
#   'outstanding_amount': 209569.41999999998,
#   'monthly_invoiced': {Period('2016-01', 'M'): 169639.84,
#    Period('2016-03', 'M'): 249499.02},
#   'monthly_paid': {Period('2016-02', 'M'): 84819.92,
#    Period('2017-04', 'M'): 124749.52},
#   'payment_status_breakdown': {'Partially Paid': 4}},
#  '281': {'total_invoices': 41,
#   'total_invoiced': 1526347.4100000001,
#   'total_paid': 1418018.49,
#   'average_days_to_pay': 13.317073170731707,
#   'late_invoices_count': 3,
#   'late_invoices_percentage': 7.317073170731707,
#   'outstanding_invoices': 6,
#   'outstanding_amount': 108328.91999999998,
#   'monthly_invoiced': {Period('2014-10', 'M'): 79851.28,
#    Period('2015-07', 'M'): 82083.12000000001,
#    Period('2015-08', 'M'): 111480.92,
#    Period('2015-10', 'M'): 61553.79,
#    Period('2015-11', 'M'): 228127.26,
#    Period('2015-12', 'M'): 89697.92,
#    Period('2016-01', 'M'): 63402.53,
#    Period('2016-02', 'M'): 63402.53,
#    Period('2016-03', 'M'): 63402.53,
#    Period('2016-04', 'M'): 81093.87,
#    Period('2016-05', 'M'): 89443.68,
#    Period('2016-06', 'M'): 146528.34,
#    Period('2016-07', 'M'): 63541.86,
#    Period('2016-08', 'M'): 63541.86,
#    Period('2016-09', 'M'): 63541.86,
#    Period('2016-10', 'M'): 63541.86,
#    Period('2016-11', 'M'): 112112.2},
#   'monthly_paid': {Period('2015-08', 'M'): 123218.63,
#    Period('2015-09', 'M'): 111480.92,
#    Period('2015-11', 'M'): 61553.79,
#    Period('2015-12', 'M'): 208405.06,
#    Period('2016-01', 'M'): 103348.83,
#    Period('2016-02', 'M'): 63402.53,
#    Period('2016-03', 'M'): 126805.06,
#    Period('2016-04', 'M'): 81093.87,
#    Period('2016-05', 'M'): 89443.68,
#    Period('2016-06', 'M'): 71324.91,
#    Period('2016-07', 'M'): 123773.76999999999,
#    Period('2016-08', 'M'): 63541.86,
#    Period('2016-09', 'M'): 63541.86,
#    Period('2016-10', 'M'): 63541.86,
#    Period('2016-11', 'M'): 30511.5,
#    Period('2017-01', 'M'): 33030.36},
#   'payment_status_breakdown': {'Fully Paid': 35, 'Partially Paid': 6}}}

# %%
import numpy as np

def numpy_to_python_type(obj):
    """Convert NumPy types to Python native types recursively."""
    if isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, dict):
        return {k: numpy_to_python_type(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [numpy_to_python_type(item) for item in obj]
    elif isinstance(obj, tuple):
        return tuple(numpy_to_python_type(item) for item in obj)
    else:
        return obj

# %%
def prepare_for_export(df, company_metrics):
    # 1. Convert to suitable formats for export
    export_df = df.copy()
    
    # Convert Period types to strings
    for col in ['Invoice Month', 'Payment Month']:
        if col in export_df.columns and pd.api.types.is_period_dtype(export_df[col]):
            export_df[col] = export_df[col].astype(str)
    
    # Convert datetime to ISO format strings
    for col in ['Date Invoiced', 'Date Paid']:
        if col in export_df.columns and pd.api.types.is_datetime64_dtype(export_df[col]):
            export_df[col] = export_df[col].dt.strftime('%Y-%m-%d')
    
    # 2. Prepare main invoice data for Supabase
    invoices_for_export = export_df.to_dict(orient='records')
    # Convert NumPy types in invoices
    invoices_for_export = numpy_to_python_type(invoices_for_export)
    
    # 3. Prepare company metrics for Supabase
    # Convert any non-serializable objects in company metrics
    company_metrics_export = {}
    for company, metrics in company_metrics.items():
        company_metrics_export[company] = {}
        for key, value in metrics.items():
            if key in ['monthly_invoiced', 'monthly_paid']:
                # Convert Period keys to strings and values to Python types
                company_metrics_export[company][key] = {
                    str(k): numpy_to_python_type(v) for k, v in value.items()
                }
            else:
                # Convert metrics values to Python types
                company_metrics_export[company][key] = numpy_to_python_type(value)
    
    return {
        'invoices': invoices_for_export,
        'company_metrics': company_metrics_export
    }
    
# Prepare data for export
export_data = prepare_for_export(enriched_df, company_metrics)

# Export to JSON files
def export_to_json(data, prefix='cleaned_data'):
    try:
        with open(f"{prefix}_invoices.json", 'w') as f:
            json.dump(data['invoices'], f)
        
        with open(f"{prefix}_company_metrics.json", 'w') as f:
            json.dump(data['company_metrics'], f)
        
        print(f"Successfully exported data to {prefix}_invoices.json and {prefix}_company_metrics.json")
    except Exception as e:
        print(f"Error exporting data: {e}")

# Export the data
export_to_json(export_data)

# Also save to CSV for alternative usage
enriched_df.to_csv('cleaned_invoice_data.csv', index=False)
print("Successfully exported data to cleaned_invoice_data.csv")
# Out:
# Successfully exported data to cleaned_data_invoices.json and cleaned_data_company_metrics.json
# Successfully exported data to cleaned_invoice_data.csv
# /var/folders/xx/bt0lfdqx57584v3465p420c80000gn/T/ipykernel_84846/3781078052.py:7: DeprecationWarning: is_period_dtype is deprecated and will be removed in a future version. Use `isinstance(dtype, pd.PeriodDtype)` instead
#   if col in export_df.columns and pd.api.types.is_period_dtype(export_df[col]):
# /var/folders/xx/bt0lfdqx57584v3465p420c80000gn/T/ipykernel_84846/3781078052.py:7: DeprecationWarning: is_period_dtype is deprecated and will be removed in a future version. Use `isinstance(dtype, pd.PeriodDtype)` instead
#   if col in export_df.columns and pd.api.types.is_period_dtype(export_df[col]):

# %%
new_df = pd.read_csv("cleaned_invoice_data.csv")
new_df.head()
# Out:
#   Date Invoiced   Date Paid  No. Days taken to Pay  Client Name  \
# 0    2022-05-31  2024-04-05                    675            1
# 1    2023-08-16  2024-04-05                    233            1
# 2    2023-08-16  2024-04-05                    233            1
# 3    2023-08-16  2024-04-05                    233            1
# 4    2019-01-31  2019-09-17                    229            1
#
#   Invoice Reference  Invoice Amount  Paid Amount  Is Duplicate  \
# 0         2022-5916       105609.74    105609.74         False
# 1         2023-6512       263821.73    263821.73          True
# 2         2023-6512        90150.94     90150.94          True
# 3         2023-6512         8442.53      8442.53          True
# 4         2019-4610       102461.41    102461.40          True
#
#    Payment Status  Is Late Invoice Month  Invoice Year Payment Month  \
# 0      Fully Paid     True       2022-05          2022       2024-04
# 1      Fully Paid     True       2023-08          2023       2024-04
# 2      Fully Paid     True       2023-08          2023       2024-04
# 3      Fully Paid     True       2023-08          2023       2024-04
# 4  Partially Paid     True       2019-01          2019       2019-09
#
#    Payment Year  Is Outstanding  Amount Due
# 0          2024           False        0.00
# 1          2024           False        0.00
# 2          2024           False        0.00
# 3          2024           False        0.00
# 4          2019            True        0.01

# %%
try:
    with open('cleaned_data_company_metrics.json', 'r') as f:
        company_metrics = json.load(f)
    
    print(f"\nCompany Metrics JSON: Successfully loaded metrics for {len(company_metrics)} companies")
    
    # Basic validation
    if len(company_metrics) > 0:
        print("  ✅ Company metrics data contains records")
        
        # Show sample of first company
        company_name = list(company_metrics.keys())[0]
        print(f"\nSample metrics for company '{company_name}':")
        metrics = company_metrics[company_name]
        for key, value in list(metrics.items())[:10]:  # Show first 10 metrics
            if isinstance(value, dict):
                print(f"  {key}: {type(value)} with {len(value)} entries")
            else:
                print(f"  {key}: {value}")
        
        # Check for required metrics
        required_metrics = ['total_invoices', 'average_days_to_pay', 'late_invoices_count']
        missing_metrics = [metric for metric in required_metrics if metric not in metrics]
        
        if missing_metrics:
            print(f"\n  ⚠️ Missing required metrics: {missing_metrics}")
        else:
            print("\n  ✅ All required metrics are present")
    else:
        print("  ⚠️ No company metrics found in the file")
except Exception as e:
    print(f"  ❌ Error loading company metrics JSON: {e}")
# Out:
# Company Metrics JSON: Successfully loaded metrics for 280 companies
#   ✅ Company metrics data contains records
#
# Sample metrics for company '1':
#   total_invoices: 115
#   total_invoiced: 30077153.9
#   total_paid: 29533057.6
#   average_days_to_pay: 93.98260869565217
#   late_invoices_count: 102
#   late_invoices_percentage: 88.69565217391305
#   outstanding_invoices: 6
#   outstanding_amount: 544096.3
#   monthly_invoiced: <class 'dict'> with 40 entries
#   monthly_paid: <class 'dict'> with 36 entries
#
#   ✅ All required metrics are present

# %%
try:
    with open('cleaned_data_invoices.json', 'r') as f:
        invoices_data = json.load(f)
    
    print(f"\nInvoices JSON: Successfully loaded {len(invoices_data)} records")
    
    # Basic validation
    if len(invoices_data) > 0:
        print("  ✅ Invoice data contains records")
        
        # Show sample of first invoice
        print("\nSample invoice record:")
        for key, value in list(invoices_data[0].items())[:10]:  # Show first 10 fields
            print(f"  {key}: {value}")
        
        # Check for required fields
        required_fields = ['Invoice Reference', 'Client Name', 'Invoice Amount', 'Paid Amount']
        missing_fields = [field for field in required_fields if field not in invoices_data[0]]
        
        if missing_fields:
            print(f"\n  ⚠️ Missing required fields: {missing_fields}")
        else:
            print("\n  ✅ All required fields are present")
    else:
        print("  ⚠️ No invoice records found in the file")
except Exception as e:
    print(f"  ❌ Error loading invoices JSON: {e}")
# Out:
# Invoices JSON: Successfully loaded 5706 records
#   ✅ Invoice data contains records
#
# Sample invoice record:
#   Date Invoiced: 2022-05-31
#   Date Paid: 2024-04-05
#   No. Days taken to Pay: 675
#   Client Name: 1
#   Invoice Reference: 2022-5916
#   Invoice Amount: 105609.74
#   Paid Amount: 105609.74
#   Is Duplicate: False
#   Payment Status: Fully Paid
#   Is Late: True
#
#   ✅ All required fields are present

# %%
import pandas as pd
import json
import uuid
import os

def add_primary_key_to_invoice_csv(input_file, output_file):
    """Add a UUID primary key to the invoice CSV file."""
    print(f"Processing invoice data from {input_file}...")
    
    # Read the CSV file
    df = pd.read_csv(input_file)
    
    # Add a UUID primary key column
    df['id'] = [str(uuid.uuid4()) for _ in range(len(df))]
    
    # Move id column to the front
    cols = df.columns.tolist()
    cols = ['id'] + [col for col in cols if col != 'id']
    df = df[cols]
    
    # Write to new CSV file
    df.to_csv(output_file, index=False)
    print(f"Successfully created {output_file} with {len(df)} records")
    
    return df

def convert_company_metrics_to_csv(input_file, output_file):
    """Convert company metrics JSON to CSV with primary key."""
    print(f"Converting company metrics from {input_file} to CSV...")
    
    # Read the JSON file
    with open(input_file, 'r') as f:
        metrics_data = json.load(f)
    
    # Create records with flattened structure
    records = []
    for company_name, metrics in metrics_data.items():
        # Extract basic metrics
        record = {
            'id': str(uuid.uuid4()),
            'client_name': company_name,
            'total_invoices': metrics.get('total_invoices', 0),
            'total_invoiced': metrics.get('total_invoiced', 0),
            'total_paid': metrics.get('total_paid', 0),
            'average_days_to_pay': metrics.get('average_days_to_pay', 0),
            'late_invoices_count': metrics.get('late_invoices_count', 0),
            'late_invoices_percentage': metrics.get('late_invoices_percentage', 0),
            'outstanding_invoices': metrics.get('outstanding_invoices', 0),
            'outstanding_amount': metrics.get('outstanding_amount', 0)
        }
        
        # Handle nested JSON structures - convert to string representation
        monthly_data = {}
        if 'monthly_invoiced' in metrics:
            monthly_data['monthly_invoiced'] = metrics['monthly_invoiced']
        if 'monthly_paid' in metrics:
            monthly_data['monthly_paid'] = metrics['monthly_paid']
            
        record['monthly_data'] = json.dumps(monthly_data) if monthly_data else None
        record['payment_status_breakdown'] = json.dumps(metrics.get('payment_status_breakdown', {}))
        
        records.append(record)
    
    # Create DataFrame and write to CSV
    df = pd.DataFrame(records)
    df.to_csv(output_file, index=False)
    print(f"Successfully created {output_file} with {len(df)} records")
    
    return df

def create_monthly_breakdown_csv(invoice_df, output_file):
    """Create a separate CSV for monthly breakdown data with a relation to company."""
    print("Creating monthly breakdown CSV for detailed time-series analysis...")
    
    # Group by client name and month to get monthly totals
    monthly_records = []
    
    # Ensure we have the needed columns
    if all(col in invoice_df.columns for col in ['Client Name', 'Invoice Month', 'Invoice Amount']):
        # Get unique client-month combinations
        grouped = invoice_df.groupby(['Client Name', 'Invoice Month']).agg({
            'Invoice Amount': 'sum',
            'Paid Amount': 'sum'
        }).reset_index()
        
        # Create records with proper relations
        for _, row in grouped.iterrows():
            monthly_records.append({
                'id': str(uuid.uuid4()),
                'client_name': row['Client Name'],
                'month': row['Invoice Month'],
                'invoiced_amount': row['Invoice Amount'],
                'paid_amount': row['Paid Amount']
            })
        
        # Create DataFrame and write to CSV
        monthly_df = pd.DataFrame(monthly_records)
        monthly_df.to_csv(output_file, index=False)
        print(f"Successfully created {output_file} with {len(monthly_df)} records")

def main():
    # Input and output file paths
    invoice_input = "cleaned_invoice_data.csv"
    company_metrics_input = "cleaned_data_company_metrics.json"
    
    invoice_output = "supabase_invoices.csv"
    company_metrics_output = "supabase_company_metrics.csv"
    monthly_breakdown_output = "supabase_monthly_breakdown.csv"
    
    # Process invoice data
    invoice_df = add_primary_key_to_invoice_csv(invoice_input, invoice_output)
    
    # Process company metrics
    convert_company_metrics_to_csv(company_metrics_input, company_metrics_output)
    
    # Create monthly breakdown CSV (optional but useful for time-series analysis)
    create_monthly_breakdown_csv(invoice_df, monthly_breakdown_output)
    
    print("\nAll files have been processed successfully!")
    print("You can now directly import these CSV files to Supabase:")
    print(f"1. {invoice_output} - Main invoice data with primary keys")
    print(f"2. {company_metrics_output} - Company metrics with primary keys")
    print(f"3. {monthly_breakdown_output} - Monthly breakdown data for time-series visualization")

if __name__ == "__main__":
    main()
# Out:
# Processing invoice data from cleaned_invoice_data.csv...
# Successfully created supabase_invoices.csv with 5706 records
# Converting company metrics from cleaned_data_company_metrics.json to CSV...
# Successfully created supabase_company_metrics.csv with 280 records
# Creating monthly breakdown CSV for detailed time-series analysis...
# Successfully created supabase_monthly_breakdown.csv with 2313 records
#
# All files have been processed successfully!
# You can now directly import these CSV files to Supabase:
# 1. supabase_invoices.csv - Main invoice data with primary keys
# 2. supabase_company_metrics.csv - Company metrics with primary keys
# 3. supabase_monthly_breakdown.csv - Monthly breakdown data for time-series visualization
